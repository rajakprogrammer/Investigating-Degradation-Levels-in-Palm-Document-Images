# %%
import pandas as pd
import numpy as np
import time as t
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
dataframe_project = pd.read_csv(r'D:\College Education\Semester 5\19CSE305 Machine Learning\Project\Coding\patches_gabor_15816_1.csv')
dataframe_project
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png          1607984           590161
# 1     MaI286_256.jpg_0_0.png          2409410           643821
# 2     MaI286_256.jpg_0_2.png          1244326           369812
# 3     MaI286_256.jpg_0_3.png          1631795           557097
# 4     MaI286_258.jpg_0_0.png           984212           433434
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png          1148726           301551
# 4306      MaI843_048_0_1.png           645854           234329
# 4307      MaI843_048_0_0.png          3120475           666772
# 4308      MaI843_047_0_8.png          1277520           612085
# 4309      MaI843_049_0_0.png          2588477           663550
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            30393367                          30586929
# 1            28341070                          27499264
# 2            30907068                          27466105
# 3            30301489                          29490085
# 4            29948438                          30600901
# ...               ...                               ...
# 4305         24516974                          27216360
# 4306         29333027                          29946293
# 4307         29133067                          29819972
# 4308         24686619                          27101002
# 4309         24945878                          27826266
#
#       LocalEnergy_0.7853981633974483_2  LocalEnergy_0.7853981633974483_3  \
# 0                             30908212                           3557712
# 1                             28892467                           3982411
# 2                             28429032                           2831793
# 3                             29306020                           4807170
# 4                             31128474                           2724761
# ...                                ...                               ...
# 4305                          30997331                           8563063
# 4306                          31494284                           6389616
# 4307                          30353781                           5961931
# 4308                          30589675                          10843015
# 4309                          30722393                           9020987
#
#       LocalEnergy_1.5707963267948966_1  LocalEnergy_1.5707963267948966_2  \
# 0                              1621138                            652953
# 1                              2402321                            644235
# 2                              1252555                            602900
# 3                              1644043                           1057676
# 4                               979870                            374437
# ...                                ...                               ...
# 4305                           1133933                            291160
# 4306                            634937                            464582
# 4307                           3086075                            357274
# 4308                           1271576                            646650
# 4309                           2577327                            397905
#
#       LocalEnergy_1.5707963267948966_3  ...  \
# 0                             29941573  ...
# 1                             27960356  ...
# 2                             30921587  ...
# 3                             29838689  ...
# 4                             30769862  ...
# ...                                ...  ...
# 4305                          24664964  ...
# 4306                          29331611  ...
# 4307                          29495865  ...
# 4308                          25356419  ...
# 4309                          25003415  ...
#
#       MeanAmplitude_0.7853981633974483_1  MeanAmplitude_0.7853981633974483_2  \
# 0                               42706367                            21992566
# 1                               45782802                            23562865
# 2                               45316007                            23315932
# 3                               41933519                            21616534
# 4                               43313769                            22282942
# ...                                  ...                                 ...
# 4305                            36116804                            18562491
# 4306                            40270695                            20714888
# 4307                            38812330                            19959629
# 4308                            35144094                            18084309
# 4309                            35094358                            18051221
#
#       MeanAmplitude_0.7853981633974483_3  MeanAmplitude_1.5707963267948966_1  \
# 0                               62263734                            65066148
# 1                               61063851                            64309685
# 2                               63392361                            65690131
# 3                               60989696                            65434755
# 4                               63965827                            66146550
# ...                                  ...                                 ...
# 4305                            61832379                            65723007
# 4306                            62239700                            66517727
# 4307                            59041573                            62365063
# 4308                            60155871                            66228896
# 4309                            58897115                            63528523
#
#       MeanAmplitude_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_3  \
# 0                                 249147                            40622791
# 1                                 252989                            43541072
# 2                                 257766                            43109193
# 3                                 472186                            40035467
# 4                                 137173                            41167720
# ...                                  ...                                 ...
# 4305                               65218                            34301160
# 4306                              119120                            38264591
# 4307                               74478                            36842285
# 4308                              176590                            33418317
# 4309                               86045                            33316845
#
#       MeanAmplitude_2.356194490192345_1  MeanAmplitude_2.356194490192345_2  \
# 0                              42675142                           21954827
# 1                              45761590                           23541111
# 2                              45296517                           23293852
# 3                              41888839                           21567725
# 4                              43298158                           22265049
# ...                                 ...                                ...
# 4305                           36116430                           18561987
# 4306                           40266947                           20706356
# 4307                           38809960                           19953819
# 4308                           35146446                           18088530
# 4309                           35091896                           18046364
#
#       MeanAmplitude_2.356194490192345_3  class
# 0                              62367472   good
# 1                              61161404   good
# 2                              63474181   good
# 3                              61148415   good
# 4                              64010694   good
# ...                                 ...    ...
# 4305                           61803126    bad
# 4306                           62337197    bad
# 4307                           59094463    bad
# 4308                           60149050    bad
# 4309                           58902170    bad
#
# [4310 rows x 26 columns]

# %%
# Importing the LabelEncoder module from scikit-learn
from sklearn import preprocessing as prep

# Creating an instance of the LabelEncoder
label_encoder = prep.LabelEncoder()

# Encoding the 'class' column in the DataFrame
dataframe_project['class'] = label_encoder.fit_transform(dataframe_project['class'])
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png          1607984           590161
# 1     MaI286_256.jpg_0_0.png          2409410           643821
# 2     MaI286_256.jpg_0_2.png          1244326           369812
# 3     MaI286_256.jpg_0_3.png          1631795           557097
# 4     MaI286_258.jpg_0_0.png           984212           433434
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png          1148726           301551
# 4306      MaI843_048_0_1.png           645854           234329
# 4307      MaI843_048_0_0.png          3120475           666772
# 4308      MaI843_047_0_8.png          1277520           612085
# 4309      MaI843_049_0_0.png          2588477           663550
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            30393367                          30586929
# 1            28341070                          27499264
# 2            30907068                          27466105
# 3            30301489                          29490085
# 4            29948438                          30600901
# ...               ...                               ...
# 4305         24516974                          27216360
# 4306         29333027                          29946293
# 4307         29133067                          29819972
# 4308         24686619                          27101002
# 4309         24945878                          27826266
#
#       LocalEnergy_0.7853981633974483_2  LocalEnergy_0.7853981633974483_3  \
# 0                             30908212                           3557712
# 1                             28892467                           3982411
# 2                             28429032                           2831793
# 3                             29306020                           4807170
# 4                             31128474                           2724761
# ...                                ...                               ...
# 4305                          30997331                           8563063
# 4306                          31494284                           6389616
# 4307                          30353781                           5961931
# 4308                          30589675                          10843015
# 4309                          30722393                           9020987
#
#       LocalEnergy_1.5707963267948966_1  LocalEnergy_1.5707963267948966_2  \
# 0                              1621138                            652953
# 1                              2402321                            644235
# 2                              1252555                            602900
# 3                              1644043                           1057676
# 4                               979870                            374437
# ...                                ...                               ...
# 4305                           1133933                            291160
# 4306                            634937                            464582
# 4307                           3086075                            357274
# 4308                           1271576                            646650
# 4309                           2577327                            397905
#
#       LocalEnergy_1.5707963267948966_3  ...  \
# 0                             29941573  ...
# 1                             27960356  ...
# 2                             30921587  ...
# 3                             29838689  ...
# 4                             30769862  ...
# ...                                ...  ...
# 4305                          24664964  ...
# 4306                          29331611  ...
# 4307                          29495865  ...
# 4308                          25356419  ...
# 4309                          25003415  ...
#
#       MeanAmplitude_0.7853981633974483_1  MeanAmplitude_0.7853981633974483_2  \
# 0                               42706367                            21992566
# 1                               45782802                            23562865
# 2                               45316007                            23315932
# 3                               41933519                            21616534
# 4                               43313769                            22282942
# ...                                  ...                                 ...
# 4305                            36116804                            18562491
# 4306                            40270695                            20714888
# 4307                            38812330                            19959629
# 4308                            35144094                            18084309
# 4309                            35094358                            18051221
#
#       MeanAmplitude_0.7853981633974483_3  MeanAmplitude_1.5707963267948966_1  \
# 0                               62263734                            65066148
# 1                               61063851                            64309685
# 2                               63392361                            65690131
# 3                               60989696                            65434755
# 4                               63965827                            66146550
# ...                                  ...                                 ...
# 4305                            61832379                            65723007
# 4306                            62239700                            66517727
# 4307                            59041573                            62365063
# 4308                            60155871                            66228896
# 4309                            58897115                            63528523
#
#       MeanAmplitude_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_3  \
# 0                                 249147                            40622791
# 1                                 252989                            43541072
# 2                                 257766                            43109193
# 3                                 472186                            40035467
# 4                                 137173                            41167720
# ...                                  ...                                 ...
# 4305                               65218                            34301160
# 4306                              119120                            38264591
# 4307                               74478                            36842285
# 4308                              176590                            33418317
# 4309                               86045                            33316845
#
#       MeanAmplitude_2.356194490192345_1  MeanAmplitude_2.356194490192345_2  \
# 0                              42675142                           21954827
# 1                              45761590                           23541111
# 2                              45296517                           23293852
# 3                              41888839                           21567725
# 4                              43298158                           22265049
# ...                                 ...                                ...
# 4305                           36116430                           18561987
# 4306                           40266947                           20706356
# 4307                           38809960                           19953819
# 4308                           35146446                           18088530
# 4309                           35091896                           18046364
#
#       MeanAmplitude_2.356194490192345_3  class
# 0                              62367472      1
# 1                              61161404      1
# 2                              63474181      1
# 3                              61148415      1
# 4                              64010694      1
# ...                                 ...    ...
# 4305                           61803126      0
# 4306                           62337197      0
# 4307                           59094463      0
# 4308                           60149050      0
# 4309                           58902170      0
#
# [4310 rows x 26 columns]

# %%
normal_scaler = prep.StandardScaler()
scaled_columns = dataframe_project.columns[1:25]
scaled_df = dataframe_project
for col in scaled_columns:
    scaled_df[col] = normal_scaler.fit_transform(scaled_df[col].values.reshape(-1, 1))
scaled_df
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png         0.206364         1.137685
# 1     MaI286_256.jpg_0_0.png         0.817664         1.323767
# 2     MaI286_256.jpg_0_2.png        -0.071022         0.373560
# 3     MaI286_256.jpg_0_3.png         0.224526         1.023026
# 4     MaI286_258.jpg_0_0.png        -0.269428         0.594188
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png        -0.143943         0.136845
# 4306      MaI843_048_0_1.png        -0.527516        -0.096267
# 4307      MaI843_048_0_0.png         1.360040         1.403357
# 4308      MaI843_047_0_8.png        -0.045703         1.213713
# 4309      MaI843_049_0_0.png         0.954250         1.392183
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            1.050212                          0.961044
# 1            0.853097                          0.674644
# 2            1.099551                          0.671568
# 3            1.041387                          0.859305
# 4            1.007478                          0.962340
# ...               ...                               ...
# 4305         0.485807                          0.648403
# 4306         0.948370                          0.901621
# 4307         0.929165                          0.889904
# 4308         0.502100                          0.637703
# 4309         0.527001                          0.704976
#
#       LocalEnergy_0.7853981633974483_2  LocalEnergy_0.7853981633974483_3  \
# 0                             0.666561                         -0.787215
# 1                             0.497735                         -0.743263
# 2                             0.458921                         -0.862340
# 3                             0.532372                         -0.657909
# 4                             0.685009                         -0.873417
# ...                                ...                               ...
# 4305                          0.674025                         -0.269214
# 4306                          0.715647                         -0.494143
# 4307                          0.620126                         -0.538403
# 4308                          0.639883                         -0.033262
# 4309                          0.650998                         -0.221823
#
#       LocalEnergy_1.5707963267948966_1  LocalEnergy_1.5707963267948966_2  \
# 0                             0.215413                          1.248537
# 1                             0.810270                          1.219416
# 2                            -0.065256                          1.081344
# 3                             0.232855                          2.600439
# 4                            -0.272901                          0.318206
# ...                                ...                               ...
# 4305                         -0.155585                          0.040035
# 4306                         -0.535561                          0.619319
# 4307                          1.330936                          0.260876
# 4308                         -0.050772                          1.227483
# 4309                          0.943534                          0.396597
#
#       LocalEnergy_1.5707963267948966_3  ...  \
# 0                             0.990115  ...
# 1                             0.800269  ...
# 2                             1.084022  ...
# 3                             0.980256  ...
# 4                             1.069484  ...
# ...                                ...  ...
# 4305                          0.484496  ...
# 4306                          0.931666  ...
# 4307                          0.947406  ...
# 4308                          0.550753  ...
# 4309                          0.516927  ...
#
#       MeanAmplitude_0.7853981633974483_1  MeanAmplitude_0.7853981633974483_2  \
# 0                               1.077631                            1.082246
# 1                               1.286252                            1.289359
# 2                               1.254597                            1.256790
# 3                               1.025223                            1.032650
# 4                               1.118821                            1.120545
# ...                                  ...                                 ...
# 4305                            0.630777                            0.629839
# 4306                            0.912462                            0.913728
# 4307                            0.813567                            0.814113
# 4308                            0.564815                            0.566770
# 4309                            0.561442                            0.562405
#
#       MeanAmplitude_0.7853981633974483_3  MeanAmplitude_1.5707963267948966_1  \
# 0                               0.726466                            0.556098
# 1                               0.676086                            0.527098
# 2                               0.773855                            0.580019
# 3                               0.672973                            0.570229
# 4                               0.797933                            0.597516
# ...                                  ...                                 ...
# 4305                            0.708355                            0.581279
# 4306                            0.725457                            0.611745
# 4307                            0.591175                            0.452550
# 4308                            0.637962                            0.600673
# 4309                            0.585110                            0.497152
#
#       MeanAmplitude_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_3  \
# 0                               1.807526                            1.081326
# 1                               1.847232                            1.289622
# 2                               1.896600                            1.258796
# 3                               4.112539                            1.039405
# 4                               0.650323                            1.120221
# ...                                  ...                                 ...
# 4305                           -0.093301                            0.630111
# 4306                            0.463753                            0.913006
# 4307                            0.002397                            0.811487
# 4308                            1.057681                            0.567096
# 4309                            0.121937                            0.559854
#
#       MeanAmplitude_2.356194490192345_1  MeanAmplitude_2.356194490192345_2  \
# 0                              1.075729                           1.077680
# 1                              1.285047                           1.286934
# 2                              1.253507                           1.254317
# 3                              1.022403                           1.026616
# 4                              1.117981                           1.118603
# ...                                 ...                                ...
# 4305                           0.630928                           0.630116
# 4306                           0.912409                           0.912989
# 4307                           0.813599                           0.813718
# 4308                           0.565145                           0.567660
# 4309                           0.561445                           0.562097
#
#       MeanAmplitude_2.356194490192345_3  class
# 0                              0.730857      1
# 1                              0.680215      1
# 2                              0.777327      1
# 3                              0.679669      1
# 4                              0.799854      1
# ...                                 ...    ...
# 4305                           0.707160      0
# 4306                           0.729585      0
# 4307                           0.593426      0
# 4308                           0.637707      0
# 4309                           0.585351      0
#
# [4310 rows x 26 columns]

# %%
dataframe_scaled_input = scaled_df.iloc[:, 1:25]
dataframe_scaled_output = scaled_df.iloc[:, 25]
scaled_input_train, scaled_input_test, scaled_output_train, scaled_output_test = train_test_split(dataframe_scaled_input, dataframe_scaled_output, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_train_res, output_train_res = sm.fit_resample(scaled_input_train, scaled_output_train.ravel())

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()

    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold:
                colName = corr_matrix.columns[i]
                col_corr.add(colName)

    return col_corr

# Applying the correlation function to the input training dataset with a threshold of 0.95
col = correlation(input_train_res, 0.95)

# Printing the correlated columns and their count
print('Correlated columns:', col)
print(len(col))
# Out:
# Correlated columns: {'MeanAmplitude_0.7853981633974483_3', 'MeanAmplitude_0_3', 'LocalEnergy_1.5707963267948966_3', 'MeanAmplitude_1.5707963267948966_3', 'MeanAmplitude_1.5707963267948966_2', 'MeanAmplitude_2.356194490192345_3', 'LocalEnergy_2.356194490192345_1', 'LocalEnergy_2.356194490192345_2', 'LocalEnergy_0.7853981633974483_2', 'MeanAmplitude_1.5707963267948966_1', 'MeanAmplitude_0_2', 'LocalEnergy_1.5707963267948966_1', 'LocalEnergy_2.356194490192345_3', 'MeanAmplitude_2.356194490192345_2', 'LocalEnergy_0.7853981633974483_1', 'MeanAmplitude_0_1', 'MeanAmplitude_0.7853981633974483_2', 'MeanAmplitude_2.356194490192345_1', 'MeanAmplitude_0.7853981633974483_1'}
# 19

# %%
dataframe_reduced = dataframe_project.drop(columns = ['LocalEnergy_1.5707963267948966_1', 'MeanAmplitude_0_3', 'MeanAmplitude_2.356194490192345_3', 'LocalEnergy_0.7853981633974483_2', 'LocalEnergy_1.5707963267948966_3', 'MeanAmplitude_0.7853981633974483_3', 'MeanAmplitude_0_1', 'MeanAmplitude_0.7853981633974483_2', 'LocalEnergy_2.356194490192345_1', 'MeanAmplitude_1.5707963267948966_3', 'MeanAmplitude_1.5707963267948966_2', 'MeanAmplitude_1.5707963267948966_1', 'MeanAmplitude_2.356194490192345_2', 'MeanAmplitude_0_2', 'MeanAmplitude_2.356194490192345_1', 'LocalEnergy_2.356194490192345_2', 'LocalEnergy_2.356194490192345_3', 'MeanAmplitude_0.7853981633974483_1'])
dataframe_reduced
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png         0.206364         1.137685
# 1     MaI286_256.jpg_0_0.png         0.817664         1.323767
# 2     MaI286_256.jpg_0_2.png        -0.071022         0.373560
# 3     MaI286_256.jpg_0_3.png         0.224526         1.023026
# 4     MaI286_258.jpg_0_0.png        -0.269428         0.594188
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png        -0.143943         0.136845
# 4306      MaI843_048_0_1.png        -0.527516        -0.096267
# 4307      MaI843_048_0_0.png         1.360040         1.403357
# 4308      MaI843_047_0_8.png        -0.045703         1.213713
# 4309      MaI843_049_0_0.png         0.954250         1.392183
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            1.050212                          0.961044
# 1            0.853097                          0.674644
# 2            1.099551                          0.671568
# 3            1.041387                          0.859305
# 4            1.007478                          0.962340
# ...               ...                               ...
# 4305         0.485807                          0.648403
# 4306         0.948370                          0.901621
# 4307         0.929165                          0.889904
# 4308         0.502100                          0.637703
# 4309         0.527001                          0.704976
#
#       LocalEnergy_0.7853981633974483_3  LocalEnergy_1.5707963267948966_2  \
# 0                            -0.787215                          1.248537
# 1                            -0.743263                          1.219416
# 2                            -0.862340                          1.081344
# 3                            -0.657909                          2.600439
# 4                            -0.873417                          0.318206
# ...                                ...                               ...
# 4305                         -0.269214                          0.040035
# 4306                         -0.494143                          0.619319
# 4307                         -0.538403                          0.260876
# 4308                         -0.033262                          1.227483
# 4309                         -0.221823                          0.396597
#
#       class
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 4305      0
# 4306      0
# 4307      0
# 4308      0
# 4309      0
#
# [4310 rows x 8 columns]

# %%
dataframe_scaled_input = dataframe_reduced.iloc[:, 1:7]
dataframe_scaled_output = dataframe_reduced.iloc[:, 7]
scaled_input_train, scaled_input_test, scaled_output_train, scaled_output_test = train_test_split(dataframe_scaled_input, dataframe_scaled_output, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_train_res, output_train_res = sm.fit_resample(scaled_input_train, scaled_output_train.ravel())
print(output_train_res)
# Out:
# [0 1 0 ... 2 2 2]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import mutual_info_classif

mi1 = mutual_info_classif(input_train_res, output_train_res)
mi1 = pd.Series(mi1)
mi1.index = input_train_res.columns
mi1.sort_values(ascending=False)
mi1.sort_values(ascending=False).plot.bar(figsize=(10, 4))
mi1_sorted = mi1.sort_values(ascending=False)

# Plot the sorted values only if the value is greater than 0
mi1_sorted[mi1_sorted > 0].plot.bar(figsize=(10, 4))
# Out:
# <Axes: >

# %%
dataframe_final = dataframe_reduced.drop(columns=['LocalEnergy_0.7853981633974483_1'])
dataframe_final
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png         0.206364         1.137685
# 1     MaI286_256.jpg_0_0.png         0.817664         1.323767
# 2     MaI286_256.jpg_0_2.png        -0.071022         0.373560
# 3     MaI286_256.jpg_0_3.png         0.224526         1.023026
# 4     MaI286_258.jpg_0_0.png        -0.269428         0.594188
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png        -0.143943         0.136845
# 4306      MaI843_048_0_1.png        -0.527516        -0.096267
# 4307      MaI843_048_0_0.png         1.360040         1.403357
# 4308      MaI843_047_0_8.png        -0.045703         1.213713
# 4309      MaI843_049_0_0.png         0.954250         1.392183
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_3  \
# 0            1.050212                         -0.787215
# 1            0.853097                         -0.743263
# 2            1.099551                         -0.862340
# 3            1.041387                         -0.657909
# 4            1.007478                         -0.873417
# ...               ...                               ...
# 4305         0.485807                         -0.269214
# 4306         0.948370                         -0.494143
# 4307         0.929165                         -0.538403
# 4308         0.502100                         -0.033262
# 4309         0.527001                         -0.221823
#
#       LocalEnergy_1.5707963267948966_2  class
# 0                             1.248537      1
# 1                             1.219416      1
# 2                             1.081344      1
# 3                             2.600439      1
# 4                             0.318206      1
# ...                                ...    ...
# 4305                          0.040035      0
# 4306                          0.619319      0
# 4307                          0.260876      0
# 4308                          1.227483      0
# 4309                          0.396597      0
#
# [4310 rows x 7 columns]

# %%
input_final = dataframe_final.iloc[:, 1:6]
output_final = dataframe_final.iloc[:, 6]
final_input_train, final_input_test, final_output_train, final_output_test = train_test_split(input_final, output_final, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_train_res, output_train_res = sm.fit_resample(final_input_train, final_output_train.ravel())

# %%
# Project data classification rules
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier()
k_range = list(range(1, 21))
param_grid = dict(n_neighbors=k_range)

scores_knn = cross_val_score(knn_model, input_final.values, output_final.values, cv = 10)
start_train_knn = t.time()
grid_search_knn = GridSearchCV(knn_model, param_grid, cv=5, scoring='accuracy', return_train_score=False,verbose=1)
grid_search_knn.fit(input_train_res, output_train_res)
end_train_knn = t.time()
training_time_knn = end_train_knn - start_train_knn
predicted_knn_train = grid_search_knn.predict(input_train_res.values)

start_test_knn = t.time()
predicted_knn_test = grid_search_knn.predict(final_input_test.values)
end_test_knn = t.time()
testing_time_knn = end_test_knn - start_test_knn
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Training data")
print(classification_report(output_train_res, predicted_knn_train))
print("Accuracy: ", accuracy_score(output_train_res, predicted_knn_train))
print("Precision: ", precision_score(output_train_res, predicted_knn_train, average='weighted'))
print("Recall: ", recall_score(output_train_res, predicted_knn_train, average='weighted'))
print("F1-score: ", f1_score(output_train_res, predicted_knn_train, average='weighted'))
print(training_time_knn, 's')
print("Testing data")
print(classification_report(final_output_test, predicted_knn_test))
print("Accuracy: ", accuracy_score(final_output_test, predicted_knn_test))
print("Precision: ", precision_score(final_output_test, predicted_knn_test, average='weighted'))
print("Recall: ", recall_score(final_output_test, predicted_knn_test, average='weighted'))
print("F1-score: ", f1_score(final_output_test, predicted_knn_test, average='weighted'))
print(testing_time_knn, 's')
print(grid_search_knn.best_params_)
print("Mean Accuracy: ",scores_knn.mean())
print("Standard Deviation: ",scores_knn.std())
# Out:
# Training data
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1442
#            1       1.00      1.00      1.00      1442
#            2       1.00      1.00      1.00      1442
#
#     accuracy                           1.00      4326
#    macro avg       1.00      1.00      1.00      4326
# weighted avg       1.00      1.00      1.00      4326
#
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1-score:  1.0
# 5.322533130645752 s
# Testing data
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71       449
#            1       0.76      0.71      0.74       621
#            2       0.44      0.52      0.47       223
#
#     accuracy                           0.68      1293
#    macro avg       0.64      0.65      0.64      1293
# weighted avg       0.69      0.68      0.68      1293
#
# Accuracy:  0.6782675947409126
# Precision:  0.6884663056515695
# Recall:  0.6782675947409126
# F1-score:  0.6823525496723485
# 0.05753374099731445 s
# {'n_neighbors': 1}
# Mean Accuracy:  0.688631090487239
# Standard Deviation:  0.08240938726670151

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegressionCV
log_regre_model = LogisticRegressionCV()
scores_log_regre = cross_val_score(log_regre_model, input_final.values, output_final.values, cv=10)
start_train_log_regre = t.time()
grid_search_log_regre = GridSearchCV(log_regre_model, param_grid={
'solver': ['lbfs', 'liblinear', 'sag', 'saga']
}, cv=5)
grid_search_log_regre.fit(input_train_res, output_train_res)
end_train_log_regre = t.time()
training_time_log_regre = end_train_log_regre - start_train_log_regre
predicted_log_regre_train = grid_search_log_regre.predict(input_train_res.values)
start_test_log_regre = t.time()
predicted_log_regre_test = grid_search_log_regre.predict(final_input_test.values)
end_test_log_regre = t.time()
testing_time_log_regre = end_test_log_regre - start_test_log_regre
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 5 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'solver' parameter of LogisticRegressionCV must be a str among {'sag', 'saga', 'newton-cholesky', 'newton-cg', 'lbfgs', 'liblinear'}. Got 'lbfs' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan 0.50393304 0.50231321 0.50231321]
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegressionCV was fitted with feature names
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LogisticRegressionCV was fitted with feature names
#   warnings.warn(

# %%
print("Training data")
print(classification_report(output_train_res, predicted_log_regre_train))
print("Accuracy: ", accuracy_score(output_train_res, predicted_log_regre_train))
print("Precision: ", precision_score(output_train_res, predicted_log_regre_train, average='weighted'))
print("Recall: ", recall_score(output_train_res, predicted_log_regre_train, average='weighted'))
print("F1-score: ", f1_score(output_train_res, predicted_log_regre_train, average='weighted'))
print(training_time_log_regre, 's')
print("Testing data")
print(classification_report(final_output_test, predicted_log_regre_test))
print("Accuracy: ", accuracy_score(final_output_test, predicted_log_regre_test))
print("Precision: ", precision_score(final_output_test, predicted_log_regre_test, average='weighted'))
print("Recall: ", recall_score(final_output_test, predicted_log_regre_test, average='weighted'))
print("F1-score: ", f1_score(final_output_test, predicted_log_regre_test, average='weighted'))
print(testing_time_log_regre, 's')
print(grid_search_log_regre.best_params_)
print("Mean Accuracy: ",scores_log_regre.mean())
print("Standard Deviation: ",scores_log_regre.std())
# Out:
# Training data
#               precision    recall  f1-score   support
#
#            0       0.54      0.62      0.58      1442
#            1       0.49      0.67      0.56      1442
#            2       0.47      0.24      0.31      1442
#
#     accuracy                           0.51      4326
#    macro avg       0.50      0.51      0.48      4326
# weighted avg       0.50      0.51      0.48      4326
#
# Accuracy:  0.505085529357374
# Precision:  0.49986817930813005
# Recall:  0.505085529357374
# F1-score:  0.4840939261883641
# 6.8368141651153564 s
# Testing data
#               precision    recall  f1-score   support
#
#            0       0.62      0.65      0.64       449
#            1       0.67      0.68      0.68       621
#            2       0.28      0.24      0.26       223
#
#     accuracy                           0.60      1293
#    macro avg       0.52      0.53      0.52      1293
# weighted avg       0.59      0.60      0.59      1293
#
# Accuracy:  0.5955143078112916
# Precision:  0.5879283742080834
# Recall:  0.5955143078112916
# F1-score:  0.5914276488994104
# 0.0010035037994384766 s
# {'solver': 'liblinear'}
# Mean Accuracy:  0.6338747099767981
# Standard Deviation:  0.14721317182974705

# %%
# Multi Layer Perceptron
# Project data classification rules
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier()
scores_mlp = cross_val_score(mlp_model, input_final.values, output_final.values, cv=10)
start_train_mlp = t.time()
grid_search_mlp = GridSearchCV(estimator=MLPClassifier(), param_grid={
'learning_rate': ["constant"],
'hidden_layer_sizes': [(100,3)],
'alpha': [0.8],
'solver': ['lbfgs', 'sgd', 'adam'],
'activation': ['identity', 'logistic', 'tanh', 'relu']
}, cv=5)
grid_search_mlp.fit(input_train_res, output_train_res)
end_train_mlp = t.time()
training_time_mlp = end_train_mlp - start_train_mlp
predicted_mlp_train = grid_search_mlp.predict(input_train_res.values)
start_test_mlp = t.time()
predicted_mlp_test = grid_search_mlp.predict(final_input_test.values)
end_test_mlp = t.time()
testing_time_mlp = end_test_mlp - start_test_mlp
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but MLPClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Training data")
print(classification_report(output_train_res, predicted_mlp_train))
print("Accuracy: ", accuracy_score(output_train_res, predicted_mlp_train))
print("Precision: ", precision_score(output_train_res, predicted_mlp_train, average='weighted'))
print("Recall: ", recall_score(output_train_res, predicted_mlp_train, average='weighted'))
print("F1-score: ", f1_score(output_train_res, predicted_mlp_train, average='weighted'))
print(training_time_mlp, 's')
print("Testing data")
print(classification_report(final_output_test, predicted_mlp_test))
print("Accuracy: ", accuracy_score(final_output_test, predicted_mlp_test))
print("Precision: ", precision_score(final_output_test, predicted_mlp_test, average='weighted'))
print("Recall: ", recall_score(final_output_test, predicted_mlp_test, average='weighted'))
print("F1-score: ", f1_score(final_output_test, predicted_mlp_test, average='weighted'))
print(testing_time_mlp, 's')
print(grid_search_mlp.best_params_)
print("Mean Accuracy: ",scores_mlp.mean())
print("Standard Deviation: ",scores_mlp.std())
# Out:
# Training data
#               precision    recall  f1-score   support
#
#            0       0.61      0.28      0.38      1442
#            1       0.62      0.05      0.09      1442
#            2       0.37      0.91      0.52      1442
#
#     accuracy                           0.41      4326
#    macro avg       0.53      0.41      0.33      4326
# weighted avg       0.53      0.41      0.33      4326
#
# Accuracy:  0.41169671752196024
# Precision:  0.5311163594030307
# Recall:  0.41169671752196024
# F1-score:  0.3330503438008574
# 139.69643330574036 s
# Testing data
#               precision    recall  f1-score   support
#
#            0       0.54      0.22      0.31       449
#            1       0.71      0.03      0.06       621
#            2       0.19      0.91      0.31       223
#
#     accuracy                           0.25      1293
#    macro avg       0.48      0.39      0.23      1293
# weighted avg       0.56      0.25      0.19      1293
#
# Accuracy:  0.24748646558391338
# Precision:  0.5642258583280961
# Recall:  0.24748646558391338
# F1-score:  0.19107727280671144
# 0.002084493637084961 s
# {'activation': 'relu', 'alpha': 0.8, 'hidden_layer_sizes': (100, 3), 'learning_rate': 'constant', 'solver': 'adam'}
# Mean Accuracy:  0.7009280742459396
# Standard Deviation:  0.08666724087930176

# %%
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
model_k_means = KMeans()
k_values = range(1, 32)
euclidean_distances = []
for k in k_values:
    k_means_model = KMeans(n_clusters=k)
    k_means_model.fit(input_final)
    euclidean_distances.append(k_means_model.inertia_)
plt.plot(k_values, euclidean_distances, 'bx-')
plt.xlabel('K values')
plt.ylabel('Euclidean distances')
plt.title('Elbow curve')
plt.show()
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
start_train_k_means = t.time()
grid_search_k_means = GridSearchCV(model_k_means, param_grid= {'n_clusters': [2, 3, 4, 5, 6]})
grid_search_k_means.fit(input_final)
end_train_k_means = t.time()
training_time_k_means = end_train_k_means - start_train_k_means
predicted_k_means_train = grid_search_k_means.predict(input_final)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score, adjusted_rand_score

# Calculating Silhouette score for K-Means
best_score_k_means = silhouette_score(output_final.values.reshape(-1, 1), predicted_k_means_train.reshape(-1, 1))

# Calculating Davies-Bouldin index for K-Means
davies_bouldin_score_k_means = davies_bouldin_score(output_final.values.reshape(-1, 1), predicted_k_means_train.reshape(-1, 1))

# Calculating Adjusted Rand Index (ARI) for K-Means
adjusted_rand_score_k_means = adjusted_rand_score(output_final, predicted_k_means_train)

# Printing metrics for training data
print("Training data")
print('Silhouette score: ', best_score_k_means)
print('Best DB index: ', davies_bouldin_score_k_means)
print('ARI score: ', adjusted_rand_score_k_means)
print('Computational time: ', training_time_k_means, 's')
print(grid_search_k_means.best_params_)
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Training data
# Silhouette score:  -0.18883132699005967
# Best DB index:  27.13254175865099
# ARI score:  0.12825227540841921
# Computational time:  1.8373167514801025 s
# {'n_clusters': 6}
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from itertools import product
import time as t

# Define the parameter grid
param_grid = {
    'n_clusters': [2, 3, 4, 5],
    'linkage': ['complete', 'average', 'single'],
    'affinity': ['euclidean', 'manhattan', 'cosine']
}

# Initialize variables to store the best score and parameters
best_score_agglo = -1
best_params_agglo = {}

# Start timing the training process
start_train_agglo = t.time()

# Iterate over all combinations of parameters
for params in product(*param_grid.values()):
    param_dict = dict(zip(param_grid.keys(), params))

    # Create an Agglomerative Clustering instance with the current parameters
    agg_cluster = AgglomerativeClustering(**param_dict)

    # Fit the model and obtain cluster labels
    labels = agg_cluster.fit_predict(input_final)

    # Calculate Silhouette score for the current combination of parameters
    score = silhouette_score(output_final.values.reshape(-1, 1), labels)

    # Print the results for each combination
    print(f"Parameters: {param_dict}, Silhouette Score: {score}")

    # Update the best score and parameters if the current combination is better
    if score > best_score_agglo:
        best_score_agglo = score
        best_params_agglo = param_dict

# Create the best Agglomerative Clustering model using the best parameters
best_agg_cluster = AgglomerativeClustering(**best_params_agglo)

# Fit the model and obtain final cluster labels
labels = best_agg_cluster.fit_predict(input_final)

# End timing the training process
end_train_agglo = t.time()

# Calculate additional clustering evaluation metrics
davies_bouldin_score_agglo = davies_bouldin_score(output_final.values.reshape(-1, 1), labels)
adjusted_rand_score_agglo = adjusted_rand_score(output_final, labels)

# Calculate the total training time
training_time_agglomerative = end_train_agglo - start_train_agglo
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: 0.12898921439082398
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: 0.15355230093498567
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: 0.004554888803682303
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: 0.12898921439082398
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.05045469065897686
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: 0.12108785760062869
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.05045469065897686
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.05045469065897686
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: 0.29197994788414755
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: 0.06236630628839428
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: 0.10554497513432393
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: -0.03788468602816308
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: 0.12915069413117983
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.11385467060934153
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: -0.10904258690067974
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.05031569076048729
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.14647030993939178
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: 0.10278922820871879
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: -0.1991896434031368
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: -0.1367378535095803
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: -0.06544960779909882
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.14609329761927928
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.1519282571708667
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: -0.11253051977309936
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.1463170714776726
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.1463170714776726
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: -0.648744311014171
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: -0.4832853114350155
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: -0.3580407866690643
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: -0.09561398042264124
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.24595653249943447
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.16379730268688772
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: -0.1431931038893038
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.14569962312224616
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.14569962312224616
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: -0.6485124730862607
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
print("\nBest Parameters: ", best_params_agglo)
print("Best Silhouette Score: ", best_score_agglo)
print('Best DB index score: ', davies_bouldin_score_agglo)
print('Best adjusted rand score: ', adjusted_rand_score_agglo)
print('Computational time: ', training_time_agglomerative, 's')
# Out:
# Best Parameters:  {'n_clusters': 2, 'linkage': 'single', 'affinity': 'cosine'}
# Best Silhouette Score:  0.29197994788414755
# Best DB index score:  2.6032384237656387
# Best adjusted rand score:  0.20583736238795464
# Computational time:  24.43716073036194 s

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from itertools import product
param_grid = {
    'min_samples': [2, 3, 4, 5, 6, 7],
    'metric': ['euclidean', 'l1', 'l2', 'manhattan'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
start_train_dbscan = t.time()
best_score_dbscan = -1
best_params_dbscan = {}
for params in product(*param_grid.values()):
    param_dict = dict(zip(param_grid.keys(), params))
    dbscan_cluster = DBSCAN(**param_dict)
    labels = dbscan_cluster.fit_predict(input_final)
    score = silhouette_score(output_final.values.reshape(-1, 1), labels)
    print(f"Parameters: {param_dict}, Silhouette Score: {score}")
    if score > best_score_dbscan:
        best_score_dbscan = score
        best_params_dbscan = param_dict

best_dbscan_cluster = DBSCAN(**best_params_dbscan)
labels = best_dbscan_cluster.fit_predict(input_final)
end_train_dbscan = t.time()
davies_bouldin_score_dbscan = davies_bouldin_score(output_final.values.reshape(-1, 1), labels)
adjusted_rand_score_dbscan = adjusted_rand_score(output_final, labels)
training_time_dbscan = end_train_dbscan - start_train_dbscan
# Out:
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.9918793503480279
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9918793503480279
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9918793503480279
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.9918793503480279
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.9580046403712297
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9580046403712297
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from itertools import product

param_grid = {
    'max_iter': [100, 200, 300, 400, 500],
    'covariance_type': ['full', 'tied', 'diag', 'spherical'],
    'n_components': [2, 3, 4, 5, 6],
    'init_params': ['kmeans', 'k-means++', 'random', 'random_from_data']
}

start_train_gmm = t.time()
best_score_gmm = -1
best_params_gmm = {}

for params in product(*param_grid.values()):
    param_dict = dict(zip(param_grid.keys(), params))
    gmm_cluster = GaussianMixture(**param_dict)
    labels = gmm_cluster.fit_predict(input_final)
    score = silhouette_score(output_final.values.reshape(-1, 1), labels)
    print(f"Parameters: {param_dict}, Silhouette Score: {score}") 
    if score > best_score_gmm:
        best_score_gmm = score
        best_params_gmm = param_dict

best_gmm_cluster = GaussianMixture(**best_params_gmm)
labels = best_gmm_cluster.fit_predict(input_final)
end_train_gmm = t.time()
davies_bouldin_score_gmm = davies_bouldin_score(output_final.values.reshape(-1, 1), labels)
adjusted_rand_score_gmm = adjusted_rand_score(output_final, labels)
training_time_gmm = end_train_gmm - start_train_gmm
# Out:
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.2907906456128396
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.2377381054821924
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.23155521904533496
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.2907906456128396
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.05246357976523636
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: 0.033278310475248
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: 0.044059427601877886
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.05392055003885253
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: 0.010578438787573337
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: 0.012858462920181295
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: 0.013250171444709233
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.059978223603734136
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.07540607214414796
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.07531200529967201
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.12339506132336987
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.04141997058032205
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.08181145739729255
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.13740397832235243
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.07820393218106222
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.12240460243618397
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.29197994788414755
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.011079145773618786
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.10603416184114278
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: -0.011981407068724642
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.151989531322351
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.026735952604069965
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.032474742442167207
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.11416638470608236
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.19725541221523615
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.14375268588259443
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.2103330758616274
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.10654359463152006
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.19585942385228483
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.16909894555111987
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.1438405018671276
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.11808054426615844
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.17971121660712427
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.14915857202888413
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.2788669501885797
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.224893770289634
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.2913196091970717
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.2913196091970717
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.2913196091970717
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.2913196091970717
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.03454244366049403
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: 0.007040402697475379
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.028289151041585258
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: 0.1338058292181191
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.1320308436014349
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.13770163897596732
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.04272801464990342
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.0472578882406423
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.14724485617960326
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.1478718066925037
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.16083830251864048
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1566205001829832
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.1799593200668415
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.18045817285001922
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.15182565998247094
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.27304009114270333
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.2856441842323602
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.2856441842323602
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.285751896514629
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.2856441842323602
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.02555911771813745
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.026105961515272006
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.023252677835233944
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: 0.03650673615788898
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.027732247991563447
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.027808317422694157
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.027911758026707843
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.18596102950180396
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.13387839525145964
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.13366470435067093
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.12996525779002327
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.20100378305889902
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.12001904660766564
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.11742415881481386
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.19132425588523122
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.11946639536424981
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.2377381054821924
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.2907906456128396
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.221562834631081
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.2377381054821924
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.05283233392929024
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: 0.043278185650071244
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: 0.043324148132845595
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.04568950348795036
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.06664412921707545
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: 0.01044872672267264
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.07861710053523838
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: 0.004812590671966594
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.07581945553999286
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.07606934065356576
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.07586170683772586
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.0754716929045278
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.1539080406169834
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.07933584796914703
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.1718539963897158
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.12312066396223392

# %%
print("\nBest Parameters: ", best_params_gmm)
print("Best Silhouette Score: ", best_score_gmm)
print('Best DB index score: ', davies_bouldin_score_gmm)
print('Best ARI score: ', adjusted_rand_score_gmm)
print('Computational time: ', training_time_gmm, 's')
# Out:
# Best Parameters:  {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}
# Best Silhouette Score:  0.29197994788414755
# Best DB index score:  2.6032384237656387
# Best ARI score:  0.20583736238795464
# Computational time:  148.42874813079834 s

# %%
predicted_k_means_label = grid_search_k_means.predict(input_final)
dataframe_final['K_Means_Label'] = predicted_k_means_label

predicted_agglo_label = best_agg_cluster.fit_predict(input_final)
dataframe_final['Agglomerative_Label'] = predicted_agglo_label

predicted_dbscan_label = best_dbscan_cluster.fit_predict(input_final)
dataframe_final['DBSCAN_Label'] = predicted_dbscan_label

predicted_gmm_label = best_gmm_cluster.fit_predict(input_final)
dataframe_final['GMM_Label'] = predicted_gmm_label
# Out:
# c:\Users\LENOVO\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_agglomerative.py:1005: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
dataframe_final.to_csv('output.csv', index=False)

# %%
silhouette_list = [best_score_k_means, best_score_agglo, best_score_dbscan, best_score_gmm]
davies_bouldin_list = [davies_bouldin_score_k_means, davies_bouldin_score_agglo, davies_bouldin_score_dbscan, davies_bouldin_score_gmm]
ari_list = [adjusted_rand_score_k_means, adjusted_rand_score_agglo, adjusted_rand_score_dbscan, adjusted_rand_score_gmm]
computational_list = [training_time_k_means, training_time_agglomerative, training_time_dbscan, training_time_gmm]
list_of_clustering = ['K-Means Clustering', 'Agglomerative Clustering', 'DBSCAN Clustering', 'Gaussian Mixture Model']

# %%
# Setting the positions for the bars
bar_width = 0.2
index = list(range(len(list_of_clustering)))
index_silhouette = [i + bar_width for i in index]
index_davies = [i + 2 * bar_width for i in index]

# Creating bars for each metric
plt.figure(figsize=(12, 6))
plt.bar(index, silhouette_list, width=bar_width, label='Silhouette score')
plt.bar(index_silhouette, davies_bouldin_list, width=bar_width, label='Davies Bouldin Index')
plt.bar(index_davies, ari_list, width=bar_width, label='Adjusted Rand Score')

# Adding labels, titles, and legends
plt.xlabel('Models')
plt.ylabel('Scores')
plt.title('Performance Metrics on the Clustering Methods')
plt.xticks([i + 1.5 * bar_width for i in index], list_of_clustering)
plt.legend()

# Displaying the plot
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(list_of_clustering, silhouette_list, color='blue', label='Silhouette Score')
plt.xlabel('Clustering Algorithms')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for Different Clustering Algorithms')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(list_of_clustering, davies_bouldin_list, color='red', label='Daives-Bouldin Score')
plt.xlabel('Clustering Algorithms')
plt.ylabel('Davies-Bouldin Score')
plt.title('Davies-Bouldin Score for Different Clustering Algorithms')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(list_of_clustering, ari_list, color='yellow', label='Adjusted Rand Score')
plt.xlabel('Clustering Algorithms')
plt.ylabel('Adjusted Rand Score')
plt.title('Adjusted Rand Score for Different Clustering Algorithms')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(list_of_clustering, computational_list, color='green', label='Computational Time')
plt.xlabel('Clustering Algorithms')
plt.ylabel('Computation Time')
plt.title('Computational Time for Different Clustering Algorithms')
plt.legend()
plt.show()
