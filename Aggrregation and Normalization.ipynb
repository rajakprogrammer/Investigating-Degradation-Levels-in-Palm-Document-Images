# %%
import pandas as pd
import numpy as np
import time as t
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
dataframe_project = pd.read_csv(r"C:\Users\DELL\Downloads\patches_gabor_15816_1.csv")
dataframe_project
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png          1607984           590161
# 1     MaI286_256.jpg_0_0.png          2409410           643821
# 2     MaI286_256.jpg_0_2.png          1244326           369812
# 3     MaI286_256.jpg_0_3.png          1631795           557097
# 4     MaI286_258.jpg_0_0.png           984212           433434
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png          1148726           301551
# 4306      MaI843_048_0_1.png           645854           234329
# 4307      MaI843_048_0_0.png          3120475           666772
# 4308      MaI843_047_0_8.png          1277520           612085
# 4309      MaI843_049_0_0.png          2588477           663550
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            30393367                          30586929
# 1            28341070                          27499264
# 2            30907068                          27466105
# 3            30301489                          29490085
# 4            29948438                          30600901
# ...               ...                               ...
# 4305         24516974                          27216360
# 4306         29333027                          29946293
# 4307         29133067                          29819972
# 4308         24686619                          27101002
# 4309         24945878                          27826266
#
#       LocalEnergy_0.7853981633974483_2  LocalEnergy_0.7853981633974483_3  \
# 0                             30908212                           3557712
# 1                             28892467                           3982411
# 2                             28429032                           2831793
# 3                             29306020                           4807170
# 4                             31128474                           2724761
# ...                                ...                               ...
# 4305                          30997331                           8563063
# 4306                          31494284                           6389616
# 4307                          30353781                           5961931
# 4308                          30589675                          10843015
# 4309                          30722393                           9020987
#
#       LocalEnergy_1.5707963267948966_1  LocalEnergy_1.5707963267948966_2  \
# 0                              1621138                            652953
# 1                              2402321                            644235
# 2                              1252555                            602900
# 3                              1644043                           1057676
# 4                               979870                            374437
# ...                                ...                               ...
# 4305                           1133933                            291160
# 4306                            634937                            464582
# 4307                           3086075                            357274
# 4308                           1271576                            646650
# 4309                           2577327                            397905
#
#       LocalEnergy_1.5707963267948966_3  ...  \
# 0                             29941573  ...
# 1                             27960356  ...
# 2                             30921587  ...
# 3                             29838689  ...
# 4                             30769862  ...
# ...                                ...  ...
# 4305                          24664964  ...
# 4306                          29331611  ...
# 4307                          29495865  ...
# 4308                          25356419  ...
# 4309                          25003415  ...
#
#       MeanAmplitude_0.7853981633974483_1  MeanAmplitude_0.7853981633974483_2  \
# 0                               42706367                            21992566
# 1                               45782802                            23562865
# 2                               45316007                            23315932
# 3                               41933519                            21616534
# 4                               43313769                            22282942
# ...                                  ...                                 ...
# 4305                            36116804                            18562491
# 4306                            40270695                            20714888
# 4307                            38812330                            19959629
# 4308                            35144094                            18084309
# 4309                            35094358                            18051221
#
#       MeanAmplitude_0.7853981633974483_3  MeanAmplitude_1.5707963267948966_1  \
# 0                               62263734                            65066148
# 1                               61063851                            64309685
# 2                               63392361                            65690131
# 3                               60989696                            65434755
# 4                               63965827                            66146550
# ...                                  ...                                 ...
# 4305                            61832379                            65723007
# 4306                            62239700                            66517727
# 4307                            59041573                            62365063
# 4308                            60155871                            66228896
# 4309                            58897115                            63528523
#
#       MeanAmplitude_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_3  \
# 0                                 249147                            40622791
# 1                                 252989                            43541072
# 2                                 257766                            43109193
# 3                                 472186                            40035467
# 4                                 137173                            41167720
# ...                                  ...                                 ...
# 4305                               65218                            34301160
# 4306                              119120                            38264591
# 4307                               74478                            36842285
# 4308                              176590                            33418317
# 4309                               86045                            33316845
#
#       MeanAmplitude_2.356194490192345_1  MeanAmplitude_2.356194490192345_2  \
# 0                              42675142                           21954827
# 1                              45761590                           23541111
# 2                              45296517                           23293852
# 3                              41888839                           21567725
# 4                              43298158                           22265049
# ...                                 ...                                ...
# 4305                           36116430                           18561987
# 4306                           40266947                           20706356
# 4307                           38809960                           19953819
# 4308                           35146446                           18088530
# 4309                           35091896                           18046364
#
#       MeanAmplitude_2.356194490192345_3  class
# 0                              62367472   good
# 1                              61161404   good
# 2                              63474181   good
# 3                              61148415   good
# 4                              64010694   good
# ...                                 ...    ...
# 4305                           61803126    bad
# 4306                           62337197    bad
# 4307                           59094463    bad
# 4308                           60149050    bad
# 4309                           58902170    bad
#
# [4310 rows x 26 columns]

# %%
from sklearn import preprocessing as prep
label_encoder = prep.LabelEncoder()
dataframe_project['class'] = label_encoder.fit_transform(dataframe_project['class'])
dataframe_project
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png          1607984           590161
# 1     MaI286_256.jpg_0_0.png          2409410           643821
# 2     MaI286_256.jpg_0_2.png          1244326           369812
# 3     MaI286_256.jpg_0_3.png          1631795           557097
# 4     MaI286_258.jpg_0_0.png           984212           433434
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png          1148726           301551
# 4306      MaI843_048_0_1.png           645854           234329
# 4307      MaI843_048_0_0.png          3120475           666772
# 4308      MaI843_047_0_8.png          1277520           612085
# 4309      MaI843_049_0_0.png          2588477           663550
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            30393367                          30586929
# 1            28341070                          27499264
# 2            30907068                          27466105
# 3            30301489                          29490085
# 4            29948438                          30600901
# ...               ...                               ...
# 4305         24516974                          27216360
# 4306         29333027                          29946293
# 4307         29133067                          29819972
# 4308         24686619                          27101002
# 4309         24945878                          27826266
#
#       LocalEnergy_0.7853981633974483_2  LocalEnergy_0.7853981633974483_3  \
# 0                             30908212                           3557712
# 1                             28892467                           3982411
# 2                             28429032                           2831793
# 3                             29306020                           4807170
# 4                             31128474                           2724761
# ...                                ...                               ...
# 4305                          30997331                           8563063
# 4306                          31494284                           6389616
# 4307                          30353781                           5961931
# 4308                          30589675                          10843015
# 4309                          30722393                           9020987
#
#       LocalEnergy_1.5707963267948966_1  LocalEnergy_1.5707963267948966_2  \
# 0                              1621138                            652953
# 1                              2402321                            644235
# 2                              1252555                            602900
# 3                              1644043                           1057676
# 4                               979870                            374437
# ...                                ...                               ...
# 4305                           1133933                            291160
# 4306                            634937                            464582
# 4307                           3086075                            357274
# 4308                           1271576                            646650
# 4309                           2577327                            397905
#
#       LocalEnergy_1.5707963267948966_3  ...  \
# 0                             29941573  ...
# 1                             27960356  ...
# 2                             30921587  ...
# 3                             29838689  ...
# 4                             30769862  ...
# ...                                ...  ...
# 4305                          24664964  ...
# 4306                          29331611  ...
# 4307                          29495865  ...
# 4308                          25356419  ...
# 4309                          25003415  ...
#
#       MeanAmplitude_0.7853981633974483_1  MeanAmplitude_0.7853981633974483_2  \
# 0                               42706367                            21992566
# 1                               45782802                            23562865
# 2                               45316007                            23315932
# 3                               41933519                            21616534
# 4                               43313769                            22282942
# ...                                  ...                                 ...
# 4305                            36116804                            18562491
# 4306                            40270695                            20714888
# 4307                            38812330                            19959629
# 4308                            35144094                            18084309
# 4309                            35094358                            18051221
#
#       MeanAmplitude_0.7853981633974483_3  MeanAmplitude_1.5707963267948966_1  \
# 0                               62263734                            65066148
# 1                               61063851                            64309685
# 2                               63392361                            65690131
# 3                               60989696                            65434755
# 4                               63965827                            66146550
# ...                                  ...                                 ...
# 4305                            61832379                            65723007
# 4306                            62239700                            66517727
# 4307                            59041573                            62365063
# 4308                            60155871                            66228896
# 4309                            58897115                            63528523
#
#       MeanAmplitude_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_3  \
# 0                                 249147                            40622791
# 1                                 252989                            43541072
# 2                                 257766                            43109193
# 3                                 472186                            40035467
# 4                                 137173                            41167720
# ...                                  ...                                 ...
# 4305                               65218                            34301160
# 4306                              119120                            38264591
# 4307                               74478                            36842285
# 4308                              176590                            33418317
# 4309                               86045                            33316845
#
#       MeanAmplitude_2.356194490192345_1  MeanAmplitude_2.356194490192345_2  \
# 0                              42675142                           21954827
# 1                              45761590                           23541111
# 2                              45296517                           23293852
# 3                              41888839                           21567725
# 4                              43298158                           22265049
# ...                                 ...                                ...
# 4305                           36116430                           18561987
# 4306                           40266947                           20706356
# 4307                           38809960                           19953819
# 4308                           35146446                           18088530
# 4309                           35091896                           18046364
#
#       MeanAmplitude_2.356194490192345_3  class
# 0                              62367472      1
# 1                              61161404      1
# 2                              63474181      1
# 3                              61148415      1
# 4                              64010694      1
# ...                                 ...    ...
# 4305                           61803126      0
# 4306                           62337197      0
# 4307                           59094463      0
# 4308                           60149050      0
# 4309                           58902170      0
#
# [4310 rows x 26 columns]

# %%
normal_scaler = prep.StandardScaler()
scaled_columns = dataframe_project.columns[1:25]
scaled_df = dataframe_project
for col in scaled_columns:
    scaled_df[col] = normal_scaler.fit_transform(scaled_df[col].values.reshape(-1, 1))
scaled_df
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png         0.206364         1.137685
# 1     MaI286_256.jpg_0_0.png         0.817664         1.323767
# 2     MaI286_256.jpg_0_2.png        -0.071022         0.373560
# 3     MaI286_256.jpg_0_3.png         0.224526         1.023026
# 4     MaI286_258.jpg_0_0.png        -0.269428         0.594188
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png        -0.143943         0.136845
# 4306      MaI843_048_0_1.png        -0.527516        -0.096267
# 4307      MaI843_048_0_0.png         1.360040         1.403357
# 4308      MaI843_047_0_8.png        -0.045703         1.213713
# 4309      MaI843_049_0_0.png         0.954250         1.392183
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_1  \
# 0            1.050212                          0.961044
# 1            0.853097                          0.674644
# 2            1.099551                          0.671568
# 3            1.041387                          0.859305
# 4            1.007478                          0.962340
# ...               ...                               ...
# 4305         0.485807                          0.648403
# 4306         0.948370                          0.901621
# 4307         0.929165                          0.889904
# 4308         0.502100                          0.637703
# 4309         0.527001                          0.704976
#
#       LocalEnergy_0.7853981633974483_2  LocalEnergy_0.7853981633974483_3  \
# 0                             0.666561                         -0.787215
# 1                             0.497735                         -0.743263
# 2                             0.458921                         -0.862340
# 3                             0.532372                         -0.657909
# 4                             0.685009                         -0.873417
# ...                                ...                               ...
# 4305                          0.674025                         -0.269214
# 4306                          0.715647                         -0.494143
# 4307                          0.620126                         -0.538403
# 4308                          0.639883                         -0.033262
# 4309                          0.650998                         -0.221823
#
#       LocalEnergy_1.5707963267948966_1  LocalEnergy_1.5707963267948966_2  \
# 0                             0.215413                          1.248537
# 1                             0.810270                          1.219416
# 2                            -0.065256                          1.081344
# 3                             0.232855                          2.600439
# 4                            -0.272901                          0.318206
# ...                                ...                               ...
# 4305                         -0.155585                          0.040035
# 4306                         -0.535561                          0.619319
# 4307                          1.330936                          0.260876
# 4308                         -0.050772                          1.227483
# 4309                          0.943534                          0.396597
#
#       LocalEnergy_1.5707963267948966_3  ...  \
# 0                             0.990115  ...
# 1                             0.800269  ...
# 2                             1.084022  ...
# 3                             0.980256  ...
# 4                             1.069484  ...
# ...                                ...  ...
# 4305                          0.484496  ...
# 4306                          0.931666  ...
# 4307                          0.947406  ...
# 4308                          0.550753  ...
# 4309                          0.516927  ...
#
#       MeanAmplitude_0.7853981633974483_1  MeanAmplitude_0.7853981633974483_2  \
# 0                               1.077631                            1.082246
# 1                               1.286252                            1.289359
# 2                               1.254597                            1.256790
# 3                               1.025223                            1.032650
# 4                               1.118821                            1.120545
# ...                                  ...                                 ...
# 4305                            0.630777                            0.629839
# 4306                            0.912462                            0.913728
# 4307                            0.813567                            0.814113
# 4308                            0.564815                            0.566770
# 4309                            0.561442                            0.562405
#
#       MeanAmplitude_0.7853981633974483_3  MeanAmplitude_1.5707963267948966_1  \
# 0                               0.726466                            0.556098
# 1                               0.676086                            0.527098
# 2                               0.773855                            0.580019
# 3                               0.672973                            0.570229
# 4                               0.797933                            0.597516
# ...                                  ...                                 ...
# 4305                            0.708355                            0.581279
# 4306                            0.725457                            0.611745
# 4307                            0.591175                            0.452550
# 4308                            0.637962                            0.600673
# 4309                            0.585110                            0.497152
#
#       MeanAmplitude_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_3  \
# 0                               1.807526                            1.081326
# 1                               1.847232                            1.289622
# 2                               1.896600                            1.258796
# 3                               4.112539                            1.039405
# 4                               0.650323                            1.120221
# ...                                  ...                                 ...
# 4305                           -0.093301                            0.630111
# 4306                            0.463753                            0.913006
# 4307                            0.002397                            0.811487
# 4308                            1.057681                            0.567096
# 4309                            0.121937                            0.559854
#
#       MeanAmplitude_2.356194490192345_1  MeanAmplitude_2.356194490192345_2  \
# 0                              1.075729                           1.077680
# 1                              1.285047                           1.286934
# 2                              1.253507                           1.254317
# 3                              1.022403                           1.026616
# 4                              1.117981                           1.118603
# ...                                 ...                                ...
# 4305                           0.630928                           0.630116
# 4306                           0.912409                           0.912989
# 4307                           0.813599                           0.813718
# 4308                           0.565145                           0.567660
# 4309                           0.561445                           0.562097
#
#       MeanAmplitude_2.356194490192345_3  class
# 0                              0.730857      1
# 1                              0.680215      1
# 2                              0.777327      1
# 3                              0.679669      1
# 4                              0.799854      1
# ...                                 ...    ...
# 4305                           0.707160      0
# 4306                           0.729585      0
# 4307                           0.593426      0
# 4308                           0.637707      0
# 4309                           0.585351      0
#
# [4310 rows x 26 columns]

# %%
dataframe_scaled_input = scaled_df.iloc[:, 1:25]
dataframe_scaled_output = scaled_df.iloc[:, 25]
scaled_input_train, scaled_input_test, scaled_output_train, scaled_output_test = train_test_split(dataframe_scaled_input, dataframe_scaled_output, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_train_res, output_train_res = sm.fit_resample(scaled_input_train, scaled_output_train.ravel())

# %%
# Project data classification rules
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
scores_dt = cross_val_score(dt_model, dataframe_scaled_input.values, dataframe_scaled_output.values, cv = 10)
start_train_dt = t.time()
grid_search_dt = GridSearchCV(dt_model, param_grid={"max_depth": [1, 2, 5, 10, 15], "max_features":  ["auto", "sqrt", "log2"], "max_leaf_nodes": [1, 5, 10, 15]}, cv=5, scoring='accuracy', return_train_score=False,verbose=1)
grid_search_dt.fit(scaled_input_train, scaled_output_train)
end_train_dt = t.time()
training_time_dt = end_train_dt - start_train_dt
predicted_dt_train = grid_search_dt.predict(scaled_input_train.values)
start_test_dt = t.time()
predicted_dt_test = grid_search_dt.predict(scaled_input_test.values)
end_test_dt = t.time()
testing_time_dt = end_test_dt - start_test_dt
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 75 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 75 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 889, in fit
#     super().fit(
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py", line 177, in fit
#     self._validate_params()
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_leaf_nodes' parameter of DecisionTreeClassifier must be an int in the range [2, inf) or None. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.6423594  0.64434999 0.64667117        nan 0.64667117
#  0.64468167 0.64335442        nan 0.64401832 0.64169605 0.64799787
#         nan 0.66125608 0.6834503  0.67418042        nan 0.6841153
#  0.67616388 0.67418152        nan 0.67649885 0.66855787 0.66390179
#         nan 0.68014398 0.70599486 0.7162636         nan 0.67385534
#  0.71063721 0.70533316        nan 0.68246681 0.70698934 0.71064215
#         nan 0.68577202 0.70632873 0.71096834        nan 0.68776811
#  0.70831823 0.71959024        nan 0.68510977 0.70665656 0.71162729
#         nan 0.68213513 0.70964274 0.71593797        nan 0.6758377
#  0.70500807 0.71063666        nan 0.68644141 0.70865046 0.72124642]
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Training data")
print(classification_report(scaled_output_train, predicted_dt_train))
print("Accuracy: ", accuracy_score(scaled_output_train, predicted_dt_train))
print("Precision: ", precision_score(scaled_output_train, predicted_dt_train, average='weighted'))
print("Recall: ", recall_score(scaled_output_train, predicted_dt_train, average='weighted'))
print("F1-score: ", f1_score(scaled_output_train, predicted_dt_train, average='weighted'))
print(training_time_dt, 's')
print("Testing data")
print(classification_report(scaled_output_test, predicted_dt_test))
print("Accuracy: ", accuracy_score(scaled_output_test, predicted_dt_test))
print("Precision: ", precision_score(scaled_output_test, predicted_dt_test, average='weighted'))
print("Recall: ", recall_score(scaled_output_test, predicted_dt_test, average='weighted'))
print("F1-score: ", f1_score(scaled_output_test, predicted_dt_test, average='weighted'))
print(testing_time_dt, 's')
print(grid_search_dt.best_params_)
print("Mean Accuracy: ",scores_dt.mean())
print("Standard Deviation: ",scores_dt.std())
# Out:
# Training data
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.66      1062
#            1       0.67      0.94      0.78      1442
#            2       0.67      0.31      0.42       513
#
#     accuracy                           0.70      3017
#    macro avg       0.71      0.61      0.62      3017
# weighted avg       0.71      0.70      0.68      3017
#
# Accuracy:  0.7003646005966192
# Precision:  0.7138072945183451
# Recall:  0.7003646005966192
# F1-score:  0.6783697324617466
# 0.09045577049255371 s
# Testing data
#               precision    recall  f1-score   support
#
#            0       0.81      0.61      0.70       449
#            1       0.69      0.94      0.79       621
#            2       0.71      0.31      0.43       223
#
#     accuracy                           0.72      1293
#    macro avg       0.74      0.62      0.64      1293
# weighted avg       0.73      0.72      0.70      1293
#
# Accuracy:  0.7208043310131477
# Precision:  0.7333940901446668
# Recall:  0.7208043310131477
# F1-score:  0.6995496239075406
# 0.0010187625885009766 s
# {'max_depth': 10, 'max_features': 'auto', 'max_leaf_nodes': 15}
# Mean Accuracy:  0.6004640371229699
# Standard Deviation:  0.0717068745046679

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()
scores_nb = cross_val_score(nb_model, dataframe_scaled_input.values, dataframe_scaled_output.values, cv=10)
start_train_nb = t.time()
grid_search_nb = GridSearchCV(nb_model, param_grid={ "var_smoothing": [10.0]}, cv=5)
grid_search_nb.fit(scaled_input_train, scaled_output_train)
end_train_nb = t.time()
training_time_nb = end_train_nb - start_train_nb
predicted_nb_train = grid_search_nb.predict(scaled_input_train.values)
start_test_nb = t.time()
predicted_nb_test = grid_search_nb.predict(scaled_input_test.values)
end_test_nb = t.time()
testing_time_nb = end_test_nb - start_test_nb
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
print("Training data")
print(classification_report(scaled_output_train, predicted_nb_train))
print("Accuracy: ", accuracy_score(scaled_output_train, predicted_nb_train))
print("Precision: ", precision_score(scaled_output_train, predicted_nb_train, average='weighted'))
print("Recall: ", recall_score(scaled_output_train, predicted_nb_train, average='weighted'))
print("F1-score: ", f1_score(scaled_output_train, predicted_nb_train, average='weighted'))
print(training_time_nb, 's')
print("Testing data")
print(classification_report(scaled_output_test, predicted_nb_test))
print("Accuracy: ", accuracy_score(scaled_output_test, predicted_nb_test))
print("Precision: ", precision_score(scaled_output_test, predicted_nb_test, average='weighted'))
print("ecall: ", recall_score(scaled_output_test, predicted_nb_test, average='weighted'))
print("F1-score: ", f1_score(scaled_output_test, predicted_nb_test, average='weighted'))
print(testing_time_nb, 's')
print(grid_search_nb.best_params_)
print("Mean Accuracy: ",scores_nb.mean())
print("Standard Deviation: ",scores_nb.std())
# Out:
# Training data
#               precision    recall  f1-score   support
#
#            0       0.73      0.48      0.58      1062
#            1       0.61      0.98      0.75      1442
#            2       0.00      0.00      0.00       513
#
#     accuracy                           0.64      3017
#    macro avg       0.45      0.49      0.44      3017
# weighted avg       0.55      0.64      0.56      3017
#
# Accuracy:  0.6363937686443487
# Precision:  0.5479378008206421
# Recall:  0.6363937686443487
# F1-score:  0.5621456806638254
# 0.03574991226196289 s
# Testing data
#               precision    recall  f1-score   support
#
#            0       0.74      0.55      0.63       449
#            1       0.63      0.97      0.77       621
#            2       0.00      0.00      0.00       223
#
#     accuracy                           0.66      1293
#    macro avg       0.46      0.51      0.47      1293
# weighted avg       0.56      0.66      0.59      1293
#
# Accuracy:  0.6604795050270689
# Precision:  0.560964639075888
# ecall:  0.6604795050270689
# F1-score:  0.5885707806080785
# 0.0010013580322265625 s
# {'var_smoothing': 10.0}
# Mean Accuracy:  0.6406032482598608
# Standard Deviation:  0.14224251725803985
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def correlation(dataset,threshold):
    col_corr=set()
    corr_matrix=dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j])>threshold:
                colName=corr_matrix.columns[i]
                col_corr.add(colName)
    return col_corr
col=correlation(input_train_res,0.95)
print('Correlated columns:',col)
print(len(col))
# Out:
# Correlated columns: {'MeanAmplitude_0.7853981633974483_2', 'MeanAmplitude_0.7853981633974483_1', 'MeanAmplitude_0_3', 'MeanAmplitude_1.5707963267948966_3', 'LocalEnergy_1.5707963267948966_3', 'LocalEnergy_2.356194490192345_2', 'MeanAmplitude_1.5707963267948966_2', 'MeanAmplitude_2.356194490192345_2', 'LocalEnergy_2.356194490192345_1', 'LocalEnergy_2.356194490192345_3', 'MeanAmplitude_0.7853981633974483_3', 'MeanAmplitude_0_1', 'MeanAmplitude_1.5707963267948966_1', 'LocalEnergy_0.7853981633974483_1', 'MeanAmplitude_2.356194490192345_1', 'LocalEnergy_1.5707963267948966_1', 'LocalEnergy_0.7853981633974483_2', 'MeanAmplitude_0_2', 'MeanAmplitude_2.356194490192345_3'}
# 19

# %%
dataframe_project_reduced = dataframe_project.drop(columns=['LocalEnergy_1.5707963267948966_1', 'LocalEnergy_0.7853981633974483_2', 'MeanAmplitude_2.356194490192345_1', 'MeanAmplitude_0.7853981633974483_2', 'LocalEnergy_0.7853981633974483_1', 'MeanAmplitude_2.356194490192345_2', 'MeanAmplitude_1.5707963267948966_3', 'MeanAmplitude_0_3', 'MeanAmplitude_2.356194490192345_3', 'LocalEnergy_1.5707963267948966_3', 'MeanAmplitude_0_2', 'LocalEnergy_2.356194490192345_3', 'LocalEnergy_2.356194490192345_2', 'MeanAmplitude_0_1', 'MeanAmplitude_0.7853981633974483_1', 'LocalEnergy_2.356194490192345_1', 'MeanAmplitude_1.5707963267948966_2', 'MeanAmplitude_0.7853981633974483_3'])
dataframe_project_reduced
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_2  \
# 0     MaI286_255.jpg_0_0.png         0.206364         1.137685
# 1     MaI286_256.jpg_0_0.png         0.817664         1.323767
# 2     MaI286_256.jpg_0_2.png        -0.071022         0.373560
# 3     MaI286_256.jpg_0_3.png         0.224526         1.023026
# 4     MaI286_258.jpg_0_0.png        -0.269428         0.594188
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png        -0.143943         0.136845
# 4306      MaI843_048_0_1.png        -0.527516        -0.096267
# 4307      MaI843_048_0_0.png         1.360040         1.403357
# 4308      MaI843_047_0_8.png        -0.045703         1.213713
# 4309      MaI843_049_0_0.png         0.954250         1.392183
#
#       LocalEnergy_0_3  LocalEnergy_0.7853981633974483_3  \
# 0            1.050212                         -0.787215
# 1            0.853097                         -0.743263
# 2            1.099551                         -0.862340
# 3            1.041387                         -0.657909
# 4            1.007478                         -0.873417
# ...               ...                               ...
# 4305         0.485807                         -0.269214
# 4306         0.948370                         -0.494143
# 4307         0.929165                         -0.538403
# 4308         0.502100                         -0.033262
# 4309         0.527001                         -0.221823
#
#       LocalEnergy_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_1  \
# 0                             1.248537                            0.556098
# 1                             1.219416                            0.527098
# 2                             1.081344                            0.580019
# 3                             2.600439                            0.570229
# 4                             0.318206                            0.597516
# ...                                ...                                 ...
# 4305                          0.040035                            0.581279
# 4306                          0.619319                            0.611745
# 4307                          0.260876                            0.452550
# 4308                          1.227483                            0.600673
# 4309                          0.396597                            0.497152
#
#       class
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...     ...
# 4305      0
# 4306      0
# 4307      0
# 4308      0
# 4309      0
#
# [4310 rows x 8 columns]

# %%
dataframe_scaled_input = dataframe_project_reduced.iloc[:, 1:7]
dataframe_scaled_output = dataframe_project_reduced.iloc[:, 7]
scaled_input_train, scaled_input_test, scaled_output_train, scaled_output_test = train_test_split(dataframe_scaled_input, dataframe_scaled_output, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_train_res, output_train_res = sm.fit_resample(scaled_input_train, scaled_output_train.ravel())
print(output_train_res)
# Out:
# [0 1 0 ... 2 2 2]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import mutual_info_classif

mi1 = mutual_info_classif(input_train_res, output_train_res)
mi1 = pd.Series(mi1)
mi1.index = input_train_res.columns
mi1.sort_values(ascending=False)
mi1.sort_values(ascending=False).plot.bar(figsize=(10, 4))
mi1_sorted = mi1.sort_values(ascending=False)

# Plot the sorted values only if the value is greater than 0
mi1_sorted[mi1_sorted > 0].plot.bar(figsize=(10, 4))
# Out:
# <Axes: >

# %%
dataframe_final = dataframe_project_reduced.drop(columns=['LocalEnergy_0_2'])
dataframe_final
# Out:
#                    ImageName  LocalEnergy_0_1  LocalEnergy_0_3  \
# 0     MaI286_255.jpg_0_0.png         0.206364         1.050212
# 1     MaI286_256.jpg_0_0.png         0.817664         0.853097
# 2     MaI286_256.jpg_0_2.png        -0.071022         1.099551
# 3     MaI286_256.jpg_0_3.png         0.224526         1.041387
# 4     MaI286_258.jpg_0_0.png        -0.269428         1.007478
# ...                      ...              ...              ...
# 4305      MaI843_047_0_0.png        -0.143943         0.485807
# 4306      MaI843_048_0_1.png        -0.527516         0.948370
# 4307      MaI843_048_0_0.png         1.360040         0.929165
# 4308      MaI843_047_0_8.png        -0.045703         0.502100
# 4309      MaI843_049_0_0.png         0.954250         0.527001
#
#       LocalEnergy_0.7853981633974483_3  LocalEnergy_1.5707963267948966_2  \
# 0                            -0.787215                          1.248537
# 1                            -0.743263                          1.219416
# 2                            -0.862340                          1.081344
# 3                            -0.657909                          2.600439
# 4                            -0.873417                          0.318206
# ...                                ...                               ...
# 4305                         -0.269214                          0.040035
# 4306                         -0.494143                          0.619319
# 4307                         -0.538403                          0.260876
# 4308                         -0.033262                          1.227483
# 4309                         -0.221823                          0.396597
#
#       MeanAmplitude_1.5707963267948966_1  class
# 0                               0.556098      1
# 1                               0.527098      1
# 2                               0.580019      1
# 3                               0.570229      1
# 4                               0.597516      1
# ...                                  ...    ...
# 4305                            0.581279      0
# 4306                            0.611745      0
# 4307                            0.452550      0
# 4308                            0.600673      0
# 4309                            0.497152      0
#
# [4310 rows x 7 columns]

# %%
input_final = dataframe_final.iloc[:, 1:6]
output_final = dataframe_final.iloc[:, 6]
final_input_train, final_input_test, final_output_train, final_output_test = train_test_split(input_final, output_final, test_size=0.3, random_state=42)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2)
input_train_res, output_train_res = sm.fit_resample(final_input_train, final_output_train.ravel())

# %%
# Project data classification rules
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier()
scores_dt = cross_val_score(dt_model, input_final.values, output_final.values, cv = 10)
start_train_dt = t.time()
grid_search_dt = GridSearchCV(dt_model, param_grid={"max_depth": [10], "max_features":  ["auto", "sqrt", "log2"], "max_leaf_nodes": [15]}, cv=5, scoring='accuracy', return_train_score=False,verbose=1)
grid_search_dt.fit(final_input_train, final_output_train)
end_train_dt = t.time()
training_time_dt = end_train_dt - start_train_dt
predicted_dt_train = grid_search_dt.predict(final_input_train.values)
start_test_dt = t.time()
predicted_dt_test = grid_search_dt.predict(final_input_test.values)
end_test_dt = t.time()
testing_time_dt = end_test_dt - start_test_dt
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
print("Training data")
print(classification_report(final_output_train, predicted_dt_train))
print("Accuracy: ", accuracy_score(final_output_train, predicted_dt_train))
print("Precision: ", precision_score(final_output_train, predicted_dt_train, average='weighted'))
print("Recall: ", recall_score(final_output_train, predicted_dt_train, average='weighted'))
print("F1-score: ", f1_score(final_output_train, predicted_dt_train, average='weighted'))
print(training_time_dt, 's')
print("Testing data")
print(classification_report(final_output_test, predicted_dt_test))
print("Accuracy: ", accuracy_score(final_output_test, predicted_dt_test))
print("Precision: ", precision_score(final_output_test, predicted_dt_test, average='weighted'))
print("Recall: ", recall_score(final_output_test, predicted_dt_test, average='weighted'))
print("F1-score: ", f1_score(final_output_test, predicted_dt_test, average='weighted'))
print(testing_time_dt, 's')
print(grid_search_dt.best_params_)
print("Mean Accuracy: ",scores_dt.mean())
print("Standard Deviation: ",scores_dt.std())
# Out:
# Training data
#               precision    recall  f1-score   support
#
#            0       0.80      0.57      0.66      1062
#            1       0.67      0.94      0.78      1442
#            2       0.67      0.31      0.42       513
#
#     accuracy                           0.70      3017
#    macro avg       0.71      0.61      0.62      3017
# weighted avg       0.71      0.70      0.68      3017
#
# Accuracy:  0.7003646005966192
# Precision:  0.7138072945183451
# Recall:  0.7003646005966192
# F1-score:  0.6783697324617466
# 0.09045577049255371 s
# Testing data
#               precision    recall  f1-score   support
#
#            0       0.81      0.61      0.70       449
#            1       0.69      0.94      0.79       621
#            2       0.71      0.31      0.43       223
#
#     accuracy                           0.72      1293
#    macro avg       0.74      0.62      0.64      1293
# weighted avg       0.73      0.72      0.70      1293
#
# Accuracy:  0.7208043310131477
# Precision:  0.7333940901446668
# Recall:  0.7208043310131477
# F1-score:  0.6995496239075406
# 0.0010187625885009766 s
# {'max_depth': 10, 'max_features': 'auto', 'max_leaf_nodes': 15}
# Mean Accuracy:  0.6004640371229699
# Standard Deviation:  0.0717068745046679

# %%
from sklearn.naive_bayes import GaussianNB
nb_model = GaussianNB()
scores_nb = cross_val_score(nb_model, input_final.values, output_final.values, cv=10)
start_train_nb = t.time()
grid_search_nb = GridSearchCV(nb_model, param_grid={ "var_smoothing": [10.0]}, cv=5)
grid_search_nb.fit(final_input_train, final_output_train)
end_train_nb = t.time()
training_time_nb = end_train_nb - start_train_nb
predicted_nb_train = grid_search_nb.predict(final_input_train.values)
start_test_nb = t.time()
predicted_nb_test = grid_search_nb.predict(final_input_test.values)
end_test_nb = t.time()
testing_time_nb = end_test_nb - start_test_nb
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(

# %%
print("Training data")
print(classification_report(final_output_train, predicted_nb_train))
print("Accuracy: ", accuracy_score(final_output_train, predicted_nb_train))
print("Precision: ", precision_score(final_output_train, predicted_nb_train, average='weighted'))
print("Recall: ", recall_score(final_output_train, predicted_nb_train, average='weighted'))
print("F1-score: ", f1_score(final_output_train, predicted_nb_train, average='weighted'))
print(training_time_nb, 's')
print("Testing data")
print(classification_report(final_output_test, predicted_nb_test))
print("Accuracy: ", accuracy_score(final_output_test, predicted_nb_test))
print("Precision: ", precision_score(final_output_test, predicted_nb_test, average='weighted'))
print("ecall: ", recall_score(final_output_test, predicted_nb_test, average='weighted'))
print("F1-score: ", f1_score(final_output_test, predicted_nb_test, average='weighted'))
print(testing_time_nb, 's')
print(grid_search_nb.best_params_)
print("Mean Accuracy: ",scores_nb.mean())
print("Standard Deviation: ",scores_nb.std())
# Out:
# Training data
#               precision    recall  f1-score   support
#
#            0       0.77      0.43      0.55      1062
#            1       0.58      0.98      0.73      1442
#            2       0.00      0.00      0.00       513
#
#     accuracy                           0.62      3017
#    macro avg       0.45      0.47      0.43      3017
# weighted avg       0.55      0.62      0.54      3017
#
# Accuracy:  0.6198210142525687
# Precision:  0.5508168819123362
# Recall:  0.6198210142525687
# F1-score:  0.5435606471542076
# 0.023273944854736328 s
# Testing data
#               precision    recall  f1-score   support
#
#            0       0.81      0.52      0.63       449
#            1       0.60      0.97      0.74       621
#            2       0.00      0.00      0.00       223
#
#     accuracy                           0.65      1293
#    macro avg       0.47      0.50      0.46      1293
# weighted avg       0.57      0.65      0.58      1293
#
# Accuracy:  0.6488785769528229
# Precision:  0.5705787628314446
# ecall:  0.6488785769528229
# F1-score:  0.5778328392600363
# 0.0 s
# {'var_smoothing': 10.0}
# Mean Accuracy:  0.637122969837587
# Standard Deviation:  0.1387315792636857
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
sm = SMOTE(random_state=2)
input_total_res, output_total_res = sm.fit_resample(input_final, output_final.ravel())

# %%
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
model_k_means = KMeans()
k_values = range(1, 32)
euclidean_distances = []
for k in k_values:
    k_means_model = KMeans(n_clusters=k)
    k_means_model.fit(input_total_res)
    euclidean_distances.append(k_means_model.inertia_)
plt.plot(k_values, euclidean_distances, 'bx-')
plt.xlabel('K values')
plt.ylabel('Euclidean distances')
plt.title('Elbow curve')
plt.show()
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
start_train_k_means = t.time()
grid_search_k_means = GridSearchCV(model_k_means, param_grid= {'n_clusters': [2, 3, 4, 5, 6]})
grid_search_k_means.fit(input_total_res)
end_train_k_means = t.time()
training_time_k_means = end_train_k_means - start_train_k_means
predicted_k_means_train = grid_search_k_means.predict(input_total_res)
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from sklearn.metrics import adjusted_rand_score
print("Training data")
print('Silhouette score: ', silhouette_score(output_total_res.reshape(-1, 1), predicted_k_means_train.reshape(-1 , 1)))
print('DB index: ', davies_bouldin_score(output_total_res.reshape(-1, 1), predicted_k_means_train.reshape(-1 , 1)))
print('ARI score: ', adjusted_rand_score(output_total_res, predicted_k_means_train))
print('Computational time: ', training_time_k_means, 's')
print(grid_search_k_means.best_params_)
# Out:
# Training data
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Silhouette score:  -0.14202621486419945
# DB index:  51.11779270940855
# ARI score:  0.09391057596847115
# Computational time:  20.047114849090576 s
# {'n_clusters': 6}
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
predicted_k_means_label = grid_search_k_means.predict(input_final)
input_final['Predicted_Label'] = predicted_k_means_label
print(input_final)
# Out:
#       LocalEnergy_0_1  LocalEnergy_0_3  LocalEnergy_0.7853981633974483_3  \
# 0            0.206364         1.050212                         -0.787215
# 1            0.817664         0.853097                         -0.743263
# 2           -0.071022         1.099551                         -0.862340
# 3            0.224526         1.041387                         -0.657909
# 4           -0.269428         1.007478                         -0.873417
# ...               ...              ...                               ...
# 4305        -0.143943         0.485807                         -0.269214
# 4306        -0.527516         0.948370                         -0.494143
# 4307         1.360040         0.929165                         -0.538403
# 4308        -0.045703         0.502100                         -0.033262
# 4309         0.954250         0.527001                         -0.221823
#
#       LocalEnergy_1.5707963267948966_2  MeanAmplitude_1.5707963267948966_1  \
# 0                             1.248537                            0.556098
# 1                             1.219416                            0.527098
# 2                             1.081344                            0.580019
# 3                             2.600439                            0.570229
# 4                             0.318206                            0.597516
# ...                                ...                                 ...
# 4305                          0.040035                            0.581279
# 4306                          0.619319                            0.611745
# 4307                          0.260876                            0.452550
# 4308                          1.227483                            0.600673
# 4309                          0.396597                            0.497152
#
#       Predicted_Label
# 0                   4
# 1                   4
# 2                   4
# 3                   4
# 4                   2
# ...               ...
# 4305                2
# 4306                2
# 4307                2
# 4308                4
# 4309                2
#
# [4310 rows x 6 columns]

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score
from itertools import product
param_grid = {
    'n_clusters': [2, 3, 4, 5],
    'linkage': [ 'complete', 'average', 'single'],
    'affinity': ['euclidean', 'manhattan', 'cosine']
}
start_train_agglo = t.time()
best_score_agglo = -1
best_params_agglo = {} 
for params in product(*param_grid.values()):
    param_dict = dict(zip(param_grid.keys(), params))
    agg_cluster = AgglomerativeClustering(**param_dict)
    labels = agg_cluster.fit_predict(input_total_res)
    score = silhouette_score(output_total_res.reshape(-1, 1), labels)
    print(f"Parameters: {param_dict}, Silhouette Score: {score}")
    if score > best_score_agglo:
        best_score_agglo = score
        best_params_agglo = param_dict

best_agg_cluster = AgglomerativeClustering(**best_params_agglo)
labels = best_agg_cluster.fit_predict(input_total_res)
end_train_agglo = t.time()
adjusted_rand_score_agglo = adjusted_rand_score(output_total_res, labels)
training_time_agglomerative = end_train_agglo - start_train_agglo
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: 0.09045778368162945
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: 0.09045778368162945
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: 0.16518653106228048
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.05340993839112703
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: 0.01082177190191173
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: 0.16518653106228048
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.054514235168061705
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: 0.16518653106228048
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 2, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: 0.16518653106228048
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: -0.15964396566394112
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: -0.2056761783129518
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: -0.0342648596362691
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.054379400339745546
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.13554424336287546
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: -0.038413878592638874
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.16489278611411468
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.16489278611411468
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 3, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: -0.3519078169982388
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: -0.24930173660072727
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: -0.19008567615123556
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: -0.08943704965442142
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.25058013692932257
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.16257002726208436
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: -0.12996055221538946
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.16537751708842394
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.16537751708842394
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 4, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: -0.3517458298425374
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'complete', 'affinity': 'euclidean'}, Silhouette Score: -0.3701884909251723
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'complete', 'affinity': 'manhattan'}, Silhouette Score: -0.22030039846686636
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'complete', 'affinity': 'cosine'}, Silhouette Score: -0.11350591616887605
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'average', 'affinity': 'euclidean'}, Silhouette Score: -0.3239356768164337
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'average', 'affinity': 'manhattan'}, Silhouette Score: -0.2639345147423297
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'average', 'affinity': 'cosine'}, Silhouette Score: -0.1768793343922875
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'single', 'affinity': 'euclidean'}, Silhouette Score: -0.16472077980048863
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'single', 'affinity': 'manhattan'}, Silhouette Score: -0.16472077980048863
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# Parameters: {'n_clusters': 5, 'linkage': 'single', 'affinity': 'cosine'}, Silhouette Score: -0.3515838424360576
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
print("\nBest Parameters: ", best_params_agglo)
print("Best Silhouette Score: ", best_score_agglo)
print('Best adjusted rand score: ', adjusted_rand_score_agglo)
print('Computational time: ', training_time_agglomerative, 's')
# Out:
# Best Parameters:  {'n_clusters': 2, 'linkage': 'complete', 'affinity': 'cosine'}
# Best Silhouette Score:  0.16518653106228048
# Best adjusted rand score:  0.09253972164623804
# Computational time:  51.814178466796875 s

# %%
from sklearn.cluster import DBSCAN
from sklearn.metrics import silhouette_score
from itertools import product
param_grid = {
    'min_samples': [2, 3, 4, 5, 6, 7],
    'metric': ['euclidean', 'l1', 'l2', 'manhattan'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute']
}
start_train_dbscan = t.time()
best_score_dbscan = -1
best_params_dbscan = {}
for params in product(*param_grid.values()):
    param_dict = dict(zip(param_grid.keys(), params))
    dbscan_cluster = DBSCAN(**param_dict)
    labels = dbscan_cluster.fit_predict(input_total_res)
    score = silhouette_score(output_total_res.reshape(-1, 1), labels)
    print(f"Parameters: {param_dict}, Silhouette Score: {score}")
    if score > best_score_dbscan:
        best_score_dbscan = score
        best_params_dbscan = param_dict

best_dbscan_cluster = DBSCAN(**best_params_dbscan)
labels = best_dbscan_cluster.fit_predict(input_total_res)
end_train_dbscan = t.time()
adjusted_rand_score_dbscan = adjusted_rand_score(output_total_res, labels)
training_time_dbscan = end_train_dbscan - start_train_dbscan
# Out:
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.9953142672483438
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9953142672483438
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9953142672483438
# Parameters: {'min_samples': 2, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.9953142672483438
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.9827112619163031
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9827112619163031
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9827112619163031
# Parameters: {'min_samples': 2, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.9827112619163031
# Parameters: {'min_samples': 2, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: -0.9953142672483438
# Parameters: {'min_samples': 2, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9953142672483438
# Parameters: {'min_samples': 2, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9953142672483438
# Parameters: {'min_samples': 2, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: -0.9953142672483438
# Parameters: {'min_samples': 2, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.9827112619163031
# Parameters: {'min_samples': 2, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9827112619163031
# Parameters: {'min_samples': 2, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9827112619163031
# Parameters: {'min_samples': 2, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.9827112619163031
# Parameters: {'min_samples': 3, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.9964453061883988
# Parameters: {'min_samples': 3, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9964453061883988
# Parameters: {'min_samples': 3, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9964453061883988
# Parameters: {'min_samples': 3, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.9964453061883988
# Parameters: {'min_samples': 3, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.9920827274196155
# Parameters: {'min_samples': 3, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9920827274196155
# Parameters: {'min_samples': 3, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9920827274196155
# Parameters: {'min_samples': 3, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.9920827274196155
# Parameters: {'min_samples': 3, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: -0.9964453061883988
# Parameters: {'min_samples': 3, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9964453061883988
# Parameters: {'min_samples': 3, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9964453061883988
# Parameters: {'min_samples': 3, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: -0.9964453061883988
# Parameters: {'min_samples': 3, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.9920827274196155
# Parameters: {'min_samples': 3, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9920827274196155
# Parameters: {'min_samples': 3, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9920827274196155
# Parameters: {'min_samples': 3, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.9920827274196155
# Parameters: {'min_samples': 4, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.6641395804863437
# Parameters: {'min_samples': 4, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.6641395804863437
# Parameters: {'min_samples': 4, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.6641395804863437
# Parameters: {'min_samples': 4, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.6641395804863437
# Parameters: {'min_samples': 4, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.9948295362740346
# Parameters: {'min_samples': 4, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9948295362740346
# Parameters: {'min_samples': 4, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9948295362740346
# Parameters: {'min_samples': 4, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.9948295362740346
# Parameters: {'min_samples': 4, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: -0.6641395804863437
# Parameters: {'min_samples': 4, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: -0.6641395804863437
# Parameters: {'min_samples': 4, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: -0.6641395804863437
# Parameters: {'min_samples': 4, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: -0.6641395804863437
# Parameters: {'min_samples': 4, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.9948295362740346
# Parameters: {'min_samples': 4, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9948295362740346
# Parameters: {'min_samples': 4, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9948295362740346
# Parameters: {'min_samples': 4, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.9948295362740346
# Parameters: {'min_samples': 5, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.20574179326601988
# Parameters: {'min_samples': 5, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.20574179326601988
# Parameters: {'min_samples': 5, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.20574179326601988
# Parameters: {'min_samples': 5, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.20574179326601988
# Parameters: {'min_samples': 5, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.9831959928906123
# Parameters: {'min_samples': 5, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9831959928906123
# Parameters: {'min_samples': 5, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9831959928906123
# Parameters: {'min_samples': 5, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.9831959928906123
# Parameters: {'min_samples': 5, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: -0.20574179326601988
# Parameters: {'min_samples': 5, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: -0.20574179326601988
# Parameters: {'min_samples': 5, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: -0.20574179326601988
# Parameters: {'min_samples': 5, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: -0.20574179326601988
# Parameters: {'min_samples': 5, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.9831959928906123
# Parameters: {'min_samples': 5, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9831959928906123
# Parameters: {'min_samples': 5, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9831959928906123
# Parameters: {'min_samples': 5, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.9831959928906123
# Parameters: {'min_samples': 6, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.10561368955794627
# Parameters: {'min_samples': 6, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.10561368955794627
# Parameters: {'min_samples': 6, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.10561368955794627
# Parameters: {'min_samples': 6, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.10561368955794627
# Parameters: {'min_samples': 6, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.9633313622512
# Parameters: {'min_samples': 6, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9633313622512
# Parameters: {'min_samples': 6, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9633313622512
# Parameters: {'min_samples': 6, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.9633313622512
# Parameters: {'min_samples': 6, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: -0.10561368955794627
# Parameters: {'min_samples': 6, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: -0.10561368955794627
# Parameters: {'min_samples': 6, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: -0.10561368955794627
# Parameters: {'min_samples': 6, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: -0.10561368955794627
# Parameters: {'min_samples': 6, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.9633313622512
# Parameters: {'min_samples': 6, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9633313622512
# Parameters: {'min_samples': 6, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9633313622512
# Parameters: {'min_samples': 6, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.9633313622512
# Parameters: {'min_samples': 7, 'metric': 'euclidean', 'algorithm': 'auto'}, Silhouette Score: -0.1038670723177975
# Parameters: {'min_samples': 7, 'metric': 'euclidean', 'algorithm': 'ball_tree'}, Silhouette Score: -0.1038670723177975
# Parameters: {'min_samples': 7, 'metric': 'euclidean', 'algorithm': 'kd_tree'}, Silhouette Score: -0.1038670723177975
# Parameters: {'min_samples': 7, 'metric': 'euclidean', 'algorithm': 'brute'}, Silhouette Score: -0.1038670723177975
# Parameters: {'min_samples': 7, 'metric': 'l1', 'algorithm': 'auto'}, Silhouette Score: -0.9867506867022136
# Parameters: {'min_samples': 7, 'metric': 'l1', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9867506867022136
# Parameters: {'min_samples': 7, 'metric': 'l1', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9867506867022136
# Parameters: {'min_samples': 7, 'metric': 'l1', 'algorithm': 'brute'}, Silhouette Score: -0.9867506867022136
# Parameters: {'min_samples': 7, 'metric': 'l2', 'algorithm': 'auto'}, Silhouette Score: -0.1038670723177975
# Parameters: {'min_samples': 7, 'metric': 'l2', 'algorithm': 'ball_tree'}, Silhouette Score: -0.1038670723177975
# Parameters: {'min_samples': 7, 'metric': 'l2', 'algorithm': 'kd_tree'}, Silhouette Score: -0.1038670723177975
# Parameters: {'min_samples': 7, 'metric': 'l2', 'algorithm': 'brute'}, Silhouette Score: -0.1038670723177975
# Parameters: {'min_samples': 7, 'metric': 'manhattan', 'algorithm': 'auto'}, Silhouette Score: -0.9867506867022136
# Parameters: {'min_samples': 7, 'metric': 'manhattan', 'algorithm': 'ball_tree'}, Silhouette Score: -0.9867506867022136
# Parameters: {'min_samples': 7, 'metric': 'manhattan', 'algorithm': 'kd_tree'}, Silhouette Score: -0.9867506867022136
# Parameters: {'min_samples': 7, 'metric': 'manhattan', 'algorithm': 'brute'}, Silhouette Score: -0.9867506867022136

# %%
print("\nBest Parameters: ", best_params_dbscan)
print("Best Silhouette Score: ", best_score_dbscan)
print('Best ARI score: ', adjusted_rand_score_dbscan)
print('Computational time: ', training_time_dbscan, 's')
# Out:
# Best Parameters:  {'min_samples': 7, 'metric': 'euclidean', 'algorithm': 'auto'}
# Best Silhouette Score:  -0.1038670723177975
# Best ARI score:  0.09697365633893092
# Computational time:  68.79818415641785 s

# %%
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_score
from itertools import product

param_grid = {
    'max_iter': [100, 200, 300, 400, 500],
    'covariance_type': ['full', 'tied', 'diag', 'spherical'],
    'n_components': [2, 3, 4, 5, 6],
    'init_params': ['kmeans', 'k-means++', 'random', 'random_from_data']
}

start_train_gmm = t.time()
best_score_gmm = -1
best_params_gmm = {}

for params in product(*param_grid.values()):
    param_dict = dict(zip(param_grid.keys(), params))
    gmm_cluster = GaussianMixture(**param_dict)
    labels = gmm_cluster.fit_predict(input_total_res)
    score = silhouette_score(output_total_res.reshape(-1, 1), labels)
    print(f"Parameters: {param_dict}, Silhouette Score: {score}") 
    if score > best_score_gmm:
        best_score_gmm = score
        best_params_gmm = param_dict

best_gmm_cluster = GaussianMixture(**best_params_gmm)
labels = best_gmm_cluster.fit_predict(input_total_res)
end_train_gmm = t.time()
adjusted_rand_score_gmm = adjusted_rand_score(output_total_res, labels)
training_time_gmm = end_train_gmm - start_train_gmm
# Out:
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.0034040352819626617
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.02877800072270504
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.005609505846965264
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.025764009837982806
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.08060374184501058
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.08193594311983324
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.04339741353695097
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.1308128681743718
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08634576228453934
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.12216943239285509
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.12896353373501357
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.20567193461340189
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.19916630560537485
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.18370140047491773
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.14239828491265985
# Parameters: {'max_iter': 100, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.14792345050197847
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.0020177166361646645
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.0004975369101185015
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.03854690039814621
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.04009003064677156
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.020337304788996025
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.12877652638373785
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.04065315922509868
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.13358691590544777
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.08854005173159973
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.14840797967304567
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.10885473035025882
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.3064672127736711
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.10946256070448805
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.16598457507991946
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.12616494754026206
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.3248699069442373
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.1963820184715147
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.21250638785051346
# Parameters: {'max_iter': 100, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.17152841676154404
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.04291856958108269
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.006289300548761913
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.0039577227764480616
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.05567681306783659
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.09661155898366795
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.09681469772992334
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.04975070846385384
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.053519739428191646
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1403628332671665
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.13662676531007514
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.15082406620202893
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.12758829829666798
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.13937115081866505
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.1280035356039565
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.14186467293102517
# Parameters: {'max_iter': 100, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.14174829825278712
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.061414451260176875
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.06150785416578467
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.020102737806870524
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.04286329226240609
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.08630940225030312
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.16074786786599843
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.08856944188653126
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.15609157267582774
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.16407362508132142
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.08926982656145917
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.1645121855146385
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.29192397567183426
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.15975590907218518
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.28098311581816326
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.20486136831724172
# Parameters: {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.3666574379527425
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.003351990633705716
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.02670852117907447
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.006441249391368201
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.02032034210167685
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.078362569284714
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.09385631825161214
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.09468164593516908
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.12097741539192962
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08647275082775403
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.08445414920629178
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.15283625364293033
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.22343512192173207
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.20065507276470218
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.1320928017973961
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.22825602541725265
# Parameters: {'max_iter': 200, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.18921241139288744
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.15165231704243665
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.009719776807257163
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.00852769082537879
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.041339476424661875
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.06740105939912266
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.032003035771447134
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: 0.0002313267476158932
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.1519221890493329
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.1493003467919352
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.13361968563163482
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.1772633420997718
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.3057560163558625
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.17086367595739968
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.3022197094167629
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.2344933437754198
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.16733545669980465
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.20716143602394743
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.20290331687998853
# Parameters: {'max_iter': 200, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.21820534981502232
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.042774621674387725
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.045282690652728504
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.0030608174007738615
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.04228670214174357
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.09752036727514121
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.09061865782013924
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.060601292227346094
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.09717747816205487
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.13788566046386638
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.13237272423465046
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.1329324658976866
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.08773842066872904
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.14135064880587173
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.14171009132834814
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.18445262645280205
# Parameters: {'max_iter': 200, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.1385433822658903
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.061414451260176875
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.06155877043227189
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.06155877043227189
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.04221110572163254
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.16759149578013732
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.08665553015112581
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.08777558222297475
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.1363508323735268
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1636761394892426
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.16576278074005282
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.15953400507791857
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.22863818098746944
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.15927239703044585
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.15761681326107066
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.2574254420290895
# Parameters: {'max_iter': 200, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.47912661961511144
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.002780138812086428
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.02746577051927408
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.0011866147635842504
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.004504979139285156
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.07837071871228381
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.08173710963326533
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.07953265321704261
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.1151998072934896
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08599289208077117
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.10413189976572877
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.12868712127946363
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1662893500731459
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.1355661371721527
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.16182054959054373
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.13597816569286905
# Parameters: {'max_iter': 300, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.1773484092518713
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.10255142341744301
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.090121945717553
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.09811673260739485
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.041339476424661875
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.02359993209687446
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.2316837142475001
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: 0.009277449857050599
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.1519221890493329
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.12917005560529785
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.35752897158105085
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.11642602892324844
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.29754999302590274
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.12236287460154852
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.13767209923094312
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1997111256354729
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.3248699069442373
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.1986863000694664
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.09580913572183161
# Parameters: {'max_iter': 300, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.3051595661373096
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.042171297024611164
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.0030608174007738615
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.004262955572380072
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.05890955485090011
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.09772252587949694
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.0970681570755825
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.0974570229096076
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.09644940966935053
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.13696779121669536
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.1336138272904907
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.11220552015988891
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.11289928986205343
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.14135064880587173
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.17987047142216242
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.19640303743123294
# Parameters: {'max_iter': 300, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.18124019201512617
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.061414451260176875
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.02178332018590099
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.021807108724110333
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: 0.03246805020879079
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.08556956333323924
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.17003582884999474
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.18160893483759438
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.08743926496711504
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.16322533011069737
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.15784391400003667
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.1510051305873528
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1892083977504463
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.15967289636696233
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.15530331291212512
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.20971542169805746
# Parameters: {'max_iter': 300, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.17955916399593183
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.002780138812086428
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: 0.009725328589881569
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.005836958034332088
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.028481181721691288
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.08046482755354727
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.08187465937310275
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.12938983520546998
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.08179330719684433
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08636926089189408
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.08672276822630703
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.1439491052662994
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.17526045307997096
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.1355661371721527
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.20411965589454256
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.27636684730600863
# Parameters: {'max_iter': 400, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.14510170552226548
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.08123438258269045
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.01064484755785447
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: -0.0003266311603601937
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.041339476424661875
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.024752607862565792
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: 0.04541072539681407
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.0999241882100854
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.1519221890493329
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.08561230930568123
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.1705930161991786
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.047950207062699916
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.29695967301407733
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.1921647582421216
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.21832702099740972
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.20303101957950667
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.324617190762795
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.15593829235387624
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.20623329127888634
# Parameters: {'max_iter': 400, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.32531342641111943
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.04291856958108269
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.05549757238783718
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.006363275789961671
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.06264276291203086
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.09681633401405519
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.09741832826032717
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.09443834077270657
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.1415930123022368
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1403628332671665
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.1126712198288235
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.0656094753359309
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.13125538462990932
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.14135064880587173
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.13998533350938255
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.19630588862007925
# Parameters: {'max_iter': 400, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.12536803728112
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.061414451260176875
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.026310674949660447
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.019301895380646195
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.021592308557901334
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.08635364235265217
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.17845784984281216
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.07547294756929589
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.08522989278553726
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.16322533011069737
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.15237243069009396
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.1615744335042538
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.16053067507821014
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.2185352181731982
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.16074554035068794
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.20328138255592043
# Parameters: {'max_iter': 400, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.20257572111092254
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.002780138812086428
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.02870712979700896
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.05092750796226761
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.028122381173009192
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.07836553671541459
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.08079597709543687
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.10792095220401969
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.08314816407763108
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.08599289208077117
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.12584204258870052
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.13011524738461258
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.12809541844488576
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.20047939827359074
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.1318419571954412
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.19168170951275829
# Parameters: {'max_iter': 500, 'covariance_type': 'full', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.15670867965177435
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.1159239529944085
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.015874436103651687
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.028008654495052007
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: 0.041339476424661875
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.045265209693631174
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.12603521726518907
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.03700607223507613
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.1519221890493329
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.06710303490001752
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: 0.04951622996816665
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.08773575375547407
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.3064672127736711
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.15959491873759746
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.16734075465816037
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.17447227021480038
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.1724087277798369
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.1943775288669005
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.17822260786188762
# Parameters: {'max_iter': 500, 'covariance_type': 'tied', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.26271903961258913
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.16518653106228048
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.04231617867040665
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.005894582523189128
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.04872059331543155
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.0028330572165920008
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.09752036727514121
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.09747850471808381
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.08686589976945601
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.0868482397756014
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.1400997801737346
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.13541659743616458
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.18758305743125192
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.11232342099640709
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.1393601461438825
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.12402397118396236
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.18829468189167686
# Parameters: {'max_iter': 500, 'covariance_type': 'diag', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.14046167150215724
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'k-means++'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'random_from_data'}, Silhouette Score: 0.1698588678507356
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'kmeans'}, Silhouette Score: -0.061414451260176875
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'k-means++'}, Silhouette Score: -0.06693246059435809
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random'}, Silhouette Score: -0.021788686978194728
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 3, 'init_params': 'random_from_data'}, Silhouette Score: -0.013775684896386961
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'kmeans'}, Silhouette Score: -0.08630940225030312
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'k-means++'}, Silhouette Score: -0.09538454728007556
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random'}, Silhouette Score: -0.08863298102983787
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 4, 'init_params': 'random_from_data'}, Silhouette Score: -0.12592847904479368
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'kmeans'}, Silhouette Score: -0.16322533011069737
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'k-means++'}, Silhouette Score: -0.16451378031340239
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random'}, Silhouette Score: -0.21226421675633816
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 5, 'init_params': 'random_from_data'}, Silhouette Score: -0.1892083977504463
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'kmeans'}, Silhouette Score: -0.15957518192761969
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'k-means++'}, Silhouette Score: -0.20565692498329186
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random'}, Silhouette Score: -0.20251147772196124
# Parameters: {'max_iter': 500, 'covariance_type': 'spherical', 'n_components': 6, 'init_params': 'random_from_data'}, Silhouette Score: -0.16020356365662503

# %%
print("\nBest Parameters: ", best_params_gmm)
print("Best Silhouette Score: ", best_score_gmm)
print('Best ARI score: ', adjusted_rand_score_gmm)
print('Computational time: ', training_time_gmm, 's')
# Out:
# Best Parameters:  {'max_iter': 100, 'covariance_type': 'spherical', 'n_components': 2, 'init_params': 'kmeans'}
# Best Silhouette Score:  0.1698588678507356
# Best ARI score:  0.0874569546571926
# Computational time:  276.01682710647583 s
